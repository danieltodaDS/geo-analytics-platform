# %% [markdown]
# # BCB PIX — adoção de pagamento digital por município

# %%
# Libs
import time
import requests
import pandas as pd

# %%
# Request

# DataBase se refere a data de inicio (offset), capturando todos os dados a partir dessa data
url = (
    "https://olinda.bcb.gov.br/olinda/servico/Pix_DadosAbertos/versao/v1/odata"
    "/TransacoesPixPorMunicipio(DataBase='201601')"
)

params = {"$format": "json"}

r = requests.get(url, params, timeout = 120)

# %%
data = r.json()
data['value'][:2]
# Out:
# [{'AnoMes': 202202,
#   'Municipio_Ibge': 4311759,
#   'Municipio': 'MANOEL VIANA',
#   'Estado_Ibge': 43,
#   'Estado': 'RIO GRANDE DO SUL',
#   'Sigla_Regiao': 'SU',
#   'Regiao': 'SUL',
#   'VL_PagadorPF': 5948465.27,
#   'QT_PagadorPF': 17864,
#   'VL_PagadorPJ': 1274988.24,
#   'QT_PagadorPJ': 1636,
#   'VL_RecebedorPF': 5728446.02,
#   'QT_RecebedorPF': 12828,
#   'VL_RecebedorPJ': 1966939.92,
#   'QT_RecebedorPJ': 3744,
#   'QT_PES_PagadorPF': 2054,
#   'QT_PES_PagadorPJ': 151,
#   'QT_PES_RecebedorPF': 1827,
#   'QT_PES_RecebedorPJ': 153},
#  {'AnoMes': 202304,
#   'Municipio_Ibge': 2927002,
#   'Municipio': 'RIO REAL',
#   'Estado_Ibge': 29,
#   'Estado': 'BAHIA',
#   'Sigla_Regiao': 'NE',
#   'Regiao': 'NORDESTE',
#   'VL_PagadorPF': 60409884.1,
#   'QT_PagadorPF': 278219,
#   'VL_PagadorPJ': 25903682.63,
#   'QT_PagadorPJ': 12349,
#   'VL_RecebedorPF': 61247709.25,
#   'QT_RecebedorPF': 210020,
#   'VL_RecebedorPJ': 26085325.94,
#   'QT_RecebedorPJ': 33238,
#   'QT_PES_PagadorPF': 14291,
#   'QT_PES_PagadorPJ': 566,
#   'QT_PES_RecebedorPF': 14802,
#   'QT_PES_RecebedorPJ': 555}]

# %%
data
# Out:
# {'@odata.context': 'https://was-p.bcnet.bcb.gov.br/olinda/servico/Pix_DadosAbertos/versao/v1/odata$metadata#_TransacoesPixPorMunicipio',
#  'value': [{'AnoMes': 202202,
#    'Municipio_Ibge': 4311759,
#    'Municipio': 'MANOEL VIANA',
#    'Estado_Ibge': 43,
#    'Estado': 'RIO GRANDE DO SUL',
#    'Sigla_Regiao': 'SU',
#    'Regiao': 'SUL',
#    'VL_PagadorPF': 5948465.27,
#    'QT_PagadorPF': 17864,
#    'VL_PagadorPJ': 1274988.24,
#    'QT_PagadorPJ': 1636,
#    'VL_RecebedorPF': 5728446.02,
#    'QT_RecebedorPF': 12828,
#    'VL_RecebedorPJ': 1966939.92,
#    'QT_RecebedorPJ': 3744,
#    'QT_PES_PagadorPF': 2054,
#    'QT_PES_PagadorPJ': 151,
#    'QT_PES_RecebedorPF': 1827,
#    'QT_PES_RecebedorPJ': 153},
#   {'AnoMes': 202304,
#    'Municipio_Ibge': 2927002,
#    'Municipio': 'RIO REAL',
#    'Estado_Ibge': 29,
#    'Estado': 'BAHIA',
#    'Sigla_Regiao': 'NE',
#    'Regiao': 'NORDESTE',
#    'VL_PagadorPF': 60409884.1,
#    'QT_PagadorPF': 278219,
#    'VL_PagadorPJ': 25903682.63,
#    'QT_PagadorPJ': 12349,
#    'VL_RecebedorPF': 61247709.25,
#    'QT_RecebedorPF': 210020,
#    'VL_RecebedorPJ': 26085325.94,
#    'QT_RecebedorPJ': 33238,
#    'QT_PES_PagadorPF': 14291,
#    'QT_PES_PagadorPJ': 566,
#    'QT_PES_RecebedorPF': 14802,
#    'QT_PES_RecebedorPJ': 555},
#   {'AnoMes': 202511,
#    'Municipio_Ibge': 3540804,
#    'Municipio': 'POTIRENDABA',
#    'Estado_Ibge': 35,
#    'Estado': 'SÃO PAULO',
#    'Sigla_Regiao': 'SE',
#    'Regiao': 'SUDESTE',
#    'VL_PagadorPF': 85492055.59,
#    'QT_PagadorPF': 342121,
#    'VL_PagadorPJ': 61190139.79,
#    'QT_PagadorPJ': 32172,
#    'VL_RecebedorPF': 88789714.11,
#    'QT_RecebedorPF': 192660,
#    'VL_RecebedorPJ': 55561592.86,
#    'QT_RecebedorPJ': 82573,
#    'QT_PES_PagadorPF': 10779,
#    'QT_PES_PagadorPJ': 1012,
#    'QT_PES_RecebedorPF': 10456,
#    'QT_PES_RecebedorPJ': 925},
#   {'AnoMes': 202401,
#    'Municipio_Ibge': 4302253,
#    'Municipio': 'BOA VISTA DO SUL',
#    'Estado_Ibge': 43,
#    'Estado': 'RIO GRANDE DO SUL',
#    'Sigla_Regiao': 'SU',
#    'Regiao': 'SUL',
#    'VL_PagadorPF': 3610350.44,
#    'QT_PagadorPF': 10670,
#    'VL_PagadorPJ': 14311310.0,
#    'QT_PagadorPJ': 1499,
#    'VL_RecebedorPF': 4278357.47,
#    'QT_RecebedorPF': 6194,
#    'VL_RecebedorPJ': 11034876.53,
#    'QT_RecebedorPJ': 1769,
#    'QT_PES_PagadorPF': 851,
#    'QT_PES_PagadorPJ': 95,
#    'QT_PES_RecebedorPF': 752,
#    'QT_PES_RecebedorPJ': 86},
#   {'AnoMes': 202408,
#    'Municipio_Ibge': 3140506,
#    'Municipio': 'MARTINHO CAMPOS',
#    'Estado_Ibge': 31,
#    'Estado': 'MINAS GERAIS',
#    'Sigla_Regiao': 'SE',
#    'Regiao': 'SUDESTE',
#    'VL_PagadorPF': 44522987.65,
#    'QT_PagadorPF': 200535,
#    'VL_PagadorPJ': 32940595.09,
#    'QT_PagadorPJ': 12797,
#    'VL_RecebedorPF': 44434260.1,
#    'QT_RecebedorPF': 113044,
#    'VL_RecebedorPJ': 44171305.79,
#    'QT_RecebedorPJ': 42227,
#    'QT_PES_PagadorPF': 7575,
#    'QT_PES_PagadorPJ': 787,
#    'QT_PES_RecebedorPF': 7392,
#    'QT_PES_RecebedorPJ': 692},
#   {'AnoMes': 202012,
#    'Municipio_Ibge': 3521408,
#    'Municipio': 'IRACEMÁPOLIS',
#    'Estado_Ibge': 35,
#    'Estado': 'SÃO PAULO',
#    'Sigla_Regiao': 'SE',
#    'Regiao': 'SUDESTE',
#    'VL_PagadorPF': 4728560.31,
#    'QT_PagadorPF': 8512,
#    'VL_PagadorPJ': 4551593.77,
#    'QT_PagadorPJ': 1270,
#    'VL_RecebedorPF': 5369037.52,
#    'QT_RecebedorPF': 8773,
#    'VL_RecebedorPJ': 3043625.99,
#    'QT_RecebedorPJ': 875,
#    'QT_PES_PagadorPF': 2350,
#    'QT_PES_PagadorPJ': 211,
#    'QT_PES_RecebedorPF': 2525,
#    'QT_PES_RecebedorPJ': 228},
#   {'AnoMes': 202602,
#    'Municipio_Ibge': 3300506,
#    'Municipio': 'BOM JARDIM',
#    'Estado_Ibge': 33,
#    'Estado': 'RIO DE JANEIRO',
#    'Sigla_Regiao': 'SE',
#    'Regiao': 'SUDESTE',
#    'VL_PagadorPF': 78564102.05,
#    'QT_PagadorPF': 404183,
#    'VL_PagadorPJ': 62523991.91,
#    'QT_PagadorPJ': 38142,
#    'VL_RecebedorPF': 77700474.04,
#    'QT_RecebedorPF': 235341,
#    'VL_RecebedorPJ': 55866714.22,
#    'QT_RecebedorPJ': 112910,
#    'QT_PES_PagadorPF': 15633,
#    'QT_PES_PagadorPJ': 1394,
#    'QT_PES_RecebedorPF': 15281,
#    'QT_PES_RecebedorPJ': 1316},
#   {'AnoMes': 202310,
#    'Municipio_Ibge': 1706258,
#    'Municipio': 'CRIXÁS DO TOCANTINS',
#    'Estado_Ibge': 17,
#    'Estado': 'TOCANTINS',
#    'Sigla_Regiao': 'NO',
#    'Regiao': 'NORTE',
#    'VL_PagadorPF': 3878359.64,
#    'QT_PagadorPF': 22744,
#    'VL_PagadorPJ': 1665050.24,
#    'QT_PagadorPJ': 804,
#    'VL_RecebedorPF': 3404756.53,
#    'QT_RecebedorPF': 12973,
#    'VL_RecebedorPJ': 1273416.59,
#    'QT_RecebedorPJ': 2008,
#    'QT_PES_PagadorPF': 743,
#    'QT_PES_PagadorPJ': 34,
#    'QT_PES_RecebedorPF': 716,
#    'QT_PES_RecebedorPJ': 28},
#   {'AnoMes': 202108,
#    'Municipio_Ibge': 1301159,
#    'Municipio': 'CAREIRO DA VÁRZEA',
#    'Estado_Ibge': 13,
#    'Estado': 'AMAZONAS',
#    'Sigla_Regiao': 'NO',
#    'Regiao': 'NORTE',
#    'VL_PagadorPF': 4192250.02,
#    'QT_PagadorPF': 27066,
#    'VL_PagadorPJ': 821742.9,
#    'QT_PagadorPJ': 520,
#    'VL_RecebedorPF': 4057789.25,
#    'QT_RecebedorPF': 23984,
#    'VL_RecebedorPJ': 924654.72,
#    'QT_RecebedorPJ': 716,
#    'QT_PES_PagadorPF': 2773,
#    'QT_PES_PagadorPJ': 64,
#    'QT_PES_RecebedorPF': 2487,
#    'QT_PES_RecebedorPJ': 49},
#   {'AnoMes': 202206,
#    'Municipio_Ibge': 4307104,
#    'Municipio': 'HERVAL',
#    'Estado_Ibge': 43,
#    'Estado': 'RIO GRANDE DO SUL',
#    'Sigla_Regiao': 'SU',
#    'Regiao': 'SUL',
#    'VL_PagadorPF': 8053278.91,
#    'QT_PagadorPF': 24042,
#    'VL_PagadorPJ': 2473028.53,
#    'QT_PagadorPJ': 1347,
#    'VL_RecebedorPF': 7123328.19,
#    'QT_RecebedorPF': 17604,
#    'VL_RecebedorPJ': 2582043.56,
#    'QT_RecebedorPJ': 3337,
#    'QT_PES_PagadorPF': 2364,
#    'QT_PES_PagadorPJ': 131,
#    'QT_PES_RecebedorPF': 2159,
#    'QT_PES_RecebedorPJ': 128},
#   {'AnoMes': 202510,
#    'Municipio_Ibge': 5216007,
#    'Municipio': 'PANAMÁ',
#    'Estado_Ibge': 52,
#    'Estado': 'GOIÁS',
#    'Sigla_Regiao': 'CO',
#    'Regiao': 'CENTRO-OESTE',
#    'VL_PagadorPF': 9094360.13,
#    'QT_PagadorPF': 45801,
#    'VL_PagadorPJ': 5064933.35,
#    'QT_PagadorPJ': 3198,
#    'VL_RecebedorPF': 9151434.56,
#    'QT_RecebedorPF': 25610,
#    'VL_RecebedorPJ': 3850538.58,
#    'QT_RecebedorPJ': 8468,
#    'QT_PES_PagadorPF': 1336,
#    'QT_PES_PagadorPJ': 117,
#    'QT_PES_RecebedorPF': 1338,
#    'QT_PES_RecebedorPJ': 101},
#   {'AnoMes': 202310,
#    'Municipio_Ibge': 5220157,
#    'Municipio': 'SÃO LUIZ DO NORTE',
#    'Estado_Ibge': 52,
#    'Estado': 'GOIÁS',
#    'Sigla_Regiao': 'CO',
#    'Regiao': 'CENTRO-OESTE',
#    'VL_PagadorPF': 11523522.94,
#    'QT_PagadorPF': 50964,
#    'VL_PagadorPJ': 3915273.79,
#    'QT_PagadorPJ': 3350,
#    'VL_RecebedorPF': 11200302.05,
#    'QT_RecebedorPF': 36961,
#    'VL_RecebedorPJ': 3522424.42,
#    'QT_RecebedorPJ': 11220,
#    'QT_PES_PagadorPF': 2116,
#    'QT_PES_PagadorPJ': 145,
#    'QT_PES_RecebedorPF': 2170,
#    'QT_PES_RecebedorPJ': 132},
#   {'AnoMes': 202606,
#    'Municipio_Ibge': 5101837,
#    'Municipio': 'BOA ESPERANÇA DO NORTE',
#    'Estado_Ibge': 51,
#    'Estado': 'MATO GROSSO',
#    'Sigla_Regiao': 'CO',
#    'Regiao': 'CENTRO-OESTE',
#    'VL_PagadorPF': 3591538.86,
#    'QT_PagadorPF': 4640,
#    'VL_PagadorPJ': 1863489.43,
#    'QT_PagadorPJ': 941,
#    'VL_RecebedorPF': 7725105.94,
#    'QT_RecebedorPF': 1950,
#    'VL_RecebedorPJ': 1923370.28,
#    'QT_RecebedorPJ': 2788,
#    'QT_PES_PagadorPF': 813,
#    'QT_PES_PagadorPJ': 126,
#    'QT_PES_RecebedorPF': 567,
#    'QT_PES_RecebedorPJ': 110},
#   {'AnoMes': 202110,
#    'Municipio_Ibge': 4304804,
#    'Municipio': 'CARLOS BARBOSA',
#    'Estado_Ibge': 43,
#    'Estado': 'RIO GRANDE DO SUL',
#    'Sigla_Regiao': 'SU',
#    'Regiao': 'SUL',
#    'VL_PagadorPF': 26528398.7,
#    'QT_PagadorPF': 71659,
#    'VL_PagadorPJ': 17588087.08,
#    'QT_PagadorPJ': 9048,
#    'VL_RecebedorPF': 24424112.09,
#    'QT_RecebedorPF': 51447,
#    'VL_RecebedorPJ': 22971241.93,
#    'QT_RecebedorPJ': 23209,
#    'QT_PES_PagadorPF': 10341,
#    'QT_PES_PagadorPJ': 1167,
#    'QT_PES_RecebedorPF': 8860,
#    'QT_PES_RecebedorPJ': 1205},
#   {'AnoMes': 202201,
#    'Municipio_Ibge': 3162500,
#    'Municipio': 'SÃO JOÃO DEL REI',
#    'Estado_Ibge': 31,
#    'Estado': 'MINAS GERAIS',
#    'Sigla_Regiao': 'SE',
#    'Regiao': 'SUDESTE',
#    'VL_PagadorPF': 102969942.83,
#    'QT_PagadorPF': 294006,
#    'VL_PagadorPJ': 66556014.37,
#    'QT_PagadorPJ': 28396,
#    'VL_RecebedorPF': 105186811.81,
#    'QT_RecebedorPF': 258809,
#    'VL_RecebedorPJ': 57833412.84,
#    'QT_RecebedorPJ': 57120,
#    'QT_PES_PagadorPF': 30381,
#    'QT_PES_PagadorPJ': 2366,
#    'QT_PES_RecebedorPF': 30587,
#    'QT_PES_RecebedorPJ': 2361},
#   {'AnoMes': 202301,
#    'Municipio_Ibge': 4215901,
#    'Municipio': 'SÃO BONIFÁCIO',
#    'Estado_Ibge': 42,
#    'Estado': 'SANTA CATARINA',
#    'Sigla_Regiao': 'SU',
#    'Regiao': 'SUL',
#    'VL_PagadorPF': 3648388.56,
#    'QT_PagadorPF': 8684,
#    'VL_PagadorPJ': 1325307.0,
#    'QT_PagadorPJ': 1016,
#    'VL_RecebedorPF': 3133605.37,
#    'QT_RecebedorPF': 5877,
#    'VL_RecebedorPJ': 2626319.09,
#    'QT_RecebedorPJ': 2400,
#    'QT_PES_PagadorPF': 976,
#    'QT_PES_PagadorPJ': 94,
#    'QT_PES_RecebedorPF': 843,
#    'QT_PES_RecebedorPJ': 85},
#   {'AnoMes': 202603,
#    'Municipio_Ibge': 3151107,
#    'Municipio': 'PIRAPETINGA',
#    'Estado_Ibge': 31,
#    'Estado': 'MINAS GERAIS',
#    'Sigla_Regiao': 'SE',
#    'Regiao': 'SUDESTE',
#    'VL_PagadorPF': 39981784.77,
#    'QT_PagadorPF': 259808,
#    'VL_PagadorPJ': 91950296.15,
#    'QT_PagadorPJ': 18441,
#    'VL_RecebedorPF': 36148689.37,
#    'QT_RecebedorPF': 133471,
#    'VL_RecebedorPJ': 95810040.01,
#    'QT_RecebedorPJ': 56219,
#    'QT_PES_PagadorPF': 6654,
#    'QT_PES_PagadorPJ': 488,
#    'QT_PES_RecebedorPF': 6571,
#    'QT_PES_RecebedorPJ': 451},
#   {'AnoMes': 202205,
#    'Municipio_Ibge': 3519071,
#    'Municipio': 'HORTOLÂNDIA',
#    'Estado_Ibge': 35,
#    'Estado': 'SÃO PAULO',
#    'Sigla_Regiao': 'SE',
#    'Regiao': 'SUDESTE',
#    'VL_PagadorPF': 459671049.67,
#    'QT_PagadorPF': 1760863,
#    'VL_PagadorPJ': 413810164.99,
#    'QT_PagadorPJ': 180408,
#    'VL_RecebedorPF': 498888820.83,
#    'QT_RecebedorPF': 1538341,
#    'VL_RecebedorPJ': 448305092.33,
#    'QT_RecebedorPJ': 247302,
#    'QT_PES_PagadorPF': 121148,
#    'QT_PES_PagadorPJ': 9044,
#    'QT_PES_RecebedorPF': 122114,
#    'QT_PES_RecebedorPJ': 8264},
#   {'AnoMes': 202307,
#    'Municipio_Ibge': 3158003,
#    'Municipio': 'SANTA MARIA DE ITABIRA',
#    'Estado_Ibge': 31,
#    'Estado': 'MINAS GERAIS',
#    'Sigla_Regiao': 'SE',
#    'Regiao': 'SUDESTE',
#    'VL_PagadorPF': 15608372.57,
#    'QT_PagadorPF': 97767,
#    'VL_PagadorPJ': 57684760.24,
#    'QT_PagadorPJ': 4843,
#    'VL_RecebedorPF': 15725768.67,
#    'QT_RecebedorPF': 59169,
#    'VL_RecebedorPJ': 28560465.34,
#    'QT_RecebedorPJ': 11835,
#    'QT_PES_PagadorPF': 4872,
#    'QT_PES_PagadorPJ': 298,
#    'QT_PES_RecebedorPF': 4816,
#    'QT_PES_RecebedorPJ': 283},
#   {'AnoMes': 202211,
#    'Municipio_Ibge': 3169109,
#    'Municipio': 'TOLEDO',
#    'Estado_Ibge': 31,
#    'Estado': 'MINAS GERAIS',
#    'Sigla_Regiao': 'SE',
#    'Regiao': 'SUDESTE',
#    'VL_PagadorPF': 11130291.22,
#    'QT_PagadorPF': 33842,
#    'VL_PagadorPJ': 18518989.95,
#    'QT_PagadorPJ': 2938,
#    'VL_RecebedorPF': 12435192.34,
#    'QT_RecebedorPF': 27428,
#    'VL_RecebedorPJ': 14266775.74,
#    'QT_RecebedorPJ': 7129,
#    'QT_PES_PagadorPF': 2439,
#    'QT_PES_PagadorPJ': 190,
#    'QT_PES_RecebedorPF': 2406,
#    'QT_PES_RecebedorPJ': 174},
#   {'AnoMes': 202201,
#    'Municipio_Ibge': 4315305,
#    'Municipio': 'QUARAÍ',
#    'Estado_Ibge': 43,
#    'Estado': 'RIO GRANDE DO SUL',
#    'Sigla_Regiao': 'SU',
#    'Regiao': 'SUL',
#    'VL_PagadorPF': 15879140.9,
#    'QT_PagadorPF': 56311,
#    'VL_PagadorPJ': 5651971.79,
#    'QT_PagadorPJ': 4736,
#    'VL_RecebedorPF': 15554942.29,
#    'QT_RecebedorPF': 46774,
#    'VL_RecebedorPJ': 5951344.0,
#    'QT_RecebedorPJ': 7970,
#    'QT_PES_PagadorPF': 6392,
#    'QT_PES_PagadorPJ': 482,
#    'QT_PES_RecebedorPF': 6016,
#    'QT_PES_RecebedorPJ': 492},
#   {'AnoMes': 202110,
#    'Municipio_Ibge': 4316956,
#    'Municipio': 'SANTA MARIA DO HERVAL',
#    'Estado_Ibge': 43,
#    'Estado': 'RIO GRANDE DO SUL',
#    'Sigla_Regiao': 'SU',
#    'Regiao': 'SUL',
#    'VL_PagadorPF': 3176770.42,
#    'QT_PagadorPF': 9615,
#    'VL_PagadorPJ': 2691672.52,
#    'QT_PagadorPJ': 828,
#    'VL_RecebedorPF': 3206212.63,
#    'QT_RecebedorPF': 7987,
#    'VL_RecebedorPJ': 3554304.78,
#    'QT_RecebedorPJ': 2083,
#    'QT_PES_PagadorPF': 1538,
#    'QT_PES_PagadorPJ': 127,
#    'QT_PES_RecebedorPF': 1309,
#    'QT_PES_RecebedorPJ': 117},
#   {'AnoMes': 202212,
#    'Municipio_Ibge': 3160009,
#    'Municipio': 'SANTO ANTÔNIO DO AVENTUREIRO',
#    'Estado_Ibge': 31,
#    'Estado': 'MINAS GERAIS',
#    'Sigla_Regiao': 'SE',
#    'Regiao': 'SUDESTE',
#    'VL_PagadorPF': 4032934.87,
#    'QT_PagadorPF': 16934,
#    'VL_PagadorPJ': 1765567.7,
#    'QT_PagadorPJ': 1390,
#    'VL_RecebedorPF': 4465475.61,
#    'QT_RecebedorPF': 13983,
#    'VL_RecebedorPJ': 1909294.84,
#    'QT_RecebedorPJ': 2634,
#    'QT_PES_PagadorPF': 1123,
#    'QT_PES_PagadorPJ': 76,
#    'QT_PES_RecebedorPF': 1136,
#    'QT_PES_RecebedorPJ': 73},
#   {'AnoMes': 202503,
#    'Municipio_Ibge': 3148707,
#    'Municipio': 'PEDRA AZUL',
#    'Estado_Ibge': 31,
#    'Estado': 'MINAS GERAIS',
#    'Sigla_Regiao': 'SE',
#    'Regiao': 'SUDESTE',
#    'VL_PagadorPF': 62476645.42,
#    'QT_PagadorPF': 489727,
#    'VL_PagadorPJ': 19416762.62,
#    'QT_PagadorPJ': 16925,
#    'VL_RecebedorPF': 60112852.11,
#    'QT_RecebedorPF': 306080,
#    'VL_RecebedorPJ': 21140980.81,
#    'QT_RecebedorPJ': 90837,
#    'QT_PES_PagadorPF': 13051,
#    'QT_PES_PagadorPJ': 561,
#    'QT_PES_RecebedorPF': 13043,
#    'QT_PES_RecebedorPJ': 522},
#   {'AnoMes': 202405,
#    'Municipio_Ibge': 4321352,
#    'Municipio': 'TAVARES',
#    'Estado_Ibge': 43,
#    'Estado': 'RIO GRANDE DO SUL',
#    'Sigla_Regiao': 'SU',
#    'Regiao': 'SUL',
#    'VL_PagadorPF': 12005883.46,
#    'QT_PagadorPF': 55940,
#    'VL_PagadorPJ': 6372910.97,
#    'QT_PagadorPJ': 3179,
#    'VL_RecebedorPF': 12221071.36,
#    'QT_RecebedorPF': 29494,
#    'VL_RecebedorPJ': 6110223.5,
#    'QT_RecebedorPJ': 13440,
#    'QT_PES_PagadorPF': 2527,
#    'QT_PES_PagadorPJ': 152,
#    'QT_PES_RecebedorPF': 2426,
#    'QT_PES_RecebedorPJ': 148},
#   {'AnoMes': 202504,
#    'Municipio_Ibge': 1500404,
#    'Municipio': 'ALENQUER',
#    'Estado_Ibge': 15,
#    'Estado': 'PARÁ',
#    'Sigla_Regiao': 'NO',
#    'Regiao': 'NORTE',
#    'VL_PagadorPF': 143351631.53,
#    'QT_PagadorPF': 1335465,
#    'VL_PagadorPJ': 26705166.87,
#    'QT_PagadorPJ': 35253,
#    'VL_RecebedorPF': 138165834.85,
#    'QT_RecebedorPF': 834219,
#    'VL_RecebedorPJ': 29068621.8,
#    'QT_RecebedorPJ': 139387,
#    'QT_PES_PagadorPF': 30738,
#    'QT_PES_PagadorPJ': 678,
#    'QT_PES_RecebedorPF': 29745,
#    'QT_PES_RecebedorPJ': 647},
#   {'AnoMes': 202402,
#    'Municipio_Ibge': 4318408,
#    'Municipio': 'SÃO JERÔNIMO',
#    'Estado_Ibge': 43,
#    'Estado': 'RIO GRANDE DO SUL',
#    'Sigla_Regiao': 'SU',
#    'Regiao': 'SUL',
#    'VL_PagadorPF': 46388603.68,
#    'QT_PagadorPF': 311846,
#    'VL_PagadorPJ': 21391956.59,
#    'QT_PagadorPJ': 18761,
#    'VL_RecebedorPF': 47299895.52,
#    'QT_RecebedorPF': 173445,
#    'VL_RecebedorPJ': 18846942.17,
#    'QT_RecebedorPJ': 59309,
#    'QT_PES_PagadorPF': 11631,
#    'QT_PES_PagadorPJ': 672,
#    'QT_PES_RecebedorPF': 11179,
#    'QT_PES_RecebedorPJ': 660},
#   {'AnoMes': 202506,
#    'Municipio_Ibge': 4314050,
#    'Municipio': 'PAROBÉ',
#    'Estado_Ibge': 43,
#    'Estado': 'RIO GRANDE DO SUL',
#    'Sigla_Regiao': 'SU',
#    'Regiao': 'SUL',
#    'VL_PagadorPF': 185823604.2,
#    'QT_PagadorPF': 1183695,
#    'VL_PagadorPJ': 182292010.12,
#    'QT_PagadorPJ': 104262,
#    'VL_RecebedorPF': 190338323.12,
#    'QT_RecebedorPF': 661950,
#    'VL_RecebedorPJ': 151025445.89,
#    'QT_RecebedorPJ': 274328,
#    'QT_PES_PagadorPF': 35641,
#    'QT_PES_PagadorPJ': 3116,
#    'QT_PES_RecebedorPF': 35256,
#    'QT_PES_RecebedorPJ': 2991},
#   {'AnoMes': 202111,
#    'Municipio_Ibge': 1504208,
#    'Municipio': 'MARABÁ',
#    'Estado_Ibge': 15,
#    'Estado': 'PARÁ',
#    'Sigla_Regiao': 'NO',
#    'Regiao': 'NORTE',
#    'VL_PagadorPF': 458704428.36,
#    'QT_PagadorPF': 1762845,
#    'VL_PagadorPJ': 508952011.0,
#    'QT_PagadorPJ': 129575,
#    'VL_RecebedorPF': 456540022.52,
#    'QT_RecebedorPF': 1586330,
#    'VL_RecebedorPJ': 405005728.41,
#    'QT_RecebedorPJ': 258441,
#    'QT_PES_PagadorPF': 108308,
#    'QT_PES_PagadorPJ': 5616,
#    'QT_PES_RecebedorPF': 111976,
#    'QT_PES_RecebedorPJ': 5472},
#   {'AnoMes': 202410,
#    'Municipio_Ibge': 3503109,
#    'Municipio': 'ARANDU',
#    'Estado_Ibge': 35,
#    'Estado': 'SÃO PAULO',
#    'Sigla_Regiao': 'SE',
#    'Regiao': 'SUDESTE',
#    'VL_PagadorPF': 17069825.47,
#    'QT_PagadorPF': 108636,
#    'VL_PagadorPJ': 4728769.95,
#    'QT_PagadorPJ': 4926,
#    'VL_RecebedorPF': 17431064.82,
#    'QT_RecebedorPF': 58300,
#    'VL_RecebedorPJ': 4562121.85,
#    'QT_RecebedorPJ': 13681,
#    'QT_PES_PagadorPF': 3673,
#    'QT_PES_PagadorPJ': 238,
#    'QT_PES_RecebedorPF': 3655,
#    'QT_PES_RecebedorPJ': 210},
#   {'AnoMes': 202404,
#    'Municipio_Ibge': 2506004,
#    'Municipio': 'ESPERANÇA',
#    'Estado_Ibge': 25,
#    'Estado': 'PARAÍBA',
#    'Sigla_Regiao': 'NE',
#    'Regiao': 'NORDESTE',
#    'VL_PagadorPF': 71735213.65,
#    'QT_PagadorPF': 458001,
#    'VL_PagadorPJ': 44778699.96,
#    'QT_PagadorPJ': 24070,
#    'VL_RecebedorPF': 71882756.48,
#    'QT_RecebedorPF': 317562,
#    'VL_RecebedorPJ': 42863494.47,
#    'QT_RecebedorPJ': 68710,
#    'QT_PES_PagadorPF': 15228,
#    'QT_PES_PagadorPJ': 981,
#    'QT_PES_RecebedorPF': 15268,
#    'QT_PES_RecebedorPJ': 869},
#   {'AnoMes': 202407,
#    'Municipio_Ibge': 3554300,
#    'Municipio': 'TEODORO SAMPAIO',
#    'Estado_Ibge': 35,
#    'Estado': 'SÃO PAULO',
#    'Sigla_Regiao': 'SE',
#    'Regiao': 'SUDESTE',
#    'VL_PagadorPF': 77132834.19,
#    'QT_PagadorPF': 432480,
#    'VL_PagadorPJ': 24872907.76,
#    'QT_PagadorPJ': 24142,
#    'VL_RecebedorPF': 74863664.63,
#    'QT_RecebedorPF': 240132,
#    'VL_RecebedorPJ': 27807402.9,
#    'QT_RecebedorPJ': 77267,
#    'QT_PES_PagadorPF': 14574,
#    'QT_PES_PagadorPJ': 778,
#    'QT_PES_RecebedorPF': 14429,
#    'QT_PES_RecebedorPJ': 763},
#   {'AnoMes': 202605,
#    'Municipio_Ibge': 4304622,
#    'Municipio': 'CAPÃO BONITO DO SUL',
#    'Estado_Ibge': 43,
#    'Estado': 'RIO GRANDE DO SUL',
#    'Sigla_Regiao': 'SU',
#    'Regiao': 'SUL',
#    'VL_PagadorPF': 6543733.73,
#    'QT_PagadorPF': 19720,
#    'VL_PagadorPJ': 3439766.22,
#    'QT_PagadorPJ': 1262,
#    'VL_RecebedorPF': 7304147.91,
#    'QT_RecebedorPF': 7689,
#    'VL_RecebedorPJ': 3370680.19,
#    'QT_RecebedorPJ': 2108,
#    'QT_PES_PagadorPF': 733,
#    'QT_PES_PagadorPJ': 54,
#    'QT_PES_RecebedorPF': 667,
#    'QT_PES_RecebedorPJ': 52},
#   {'AnoMes': 202506,
#    'Municipio_Ibge': 3140803,
#    'Municipio': 'MATIAS BARBOSA',
#    'Estado_Ibge': 31,
#    'Estado': 'MINAS GERAIS',
#    'Sigla_Regiao': 'SE',
#    'Regiao': 'SUDESTE',
#    'VL_PagadorPF': 40490593.61,
#    'QT_PagadorPF': 252058,
#    'VL_PagadorPJ': 134824468.3,
#    'QT_PagadorPJ': 26361,
#    'VL_RecebedorPF': 40974593.59,
#    'QT_RecebedorPF': 151220,
#    'VL_RecebedorPJ': 106401084.13,
#    'QT_RecebedorPJ': 68310,
#    'QT_PES_PagadorPF': 8305,
#    'QT_PES_PagadorPJ': 797,
#    'QT_PES_RecebedorPF': 8252,
#    'QT_PES_RecebedorPJ': 761},
#   {'AnoMes': 202112,
#    'Municipio_Ibge': 2807006,
#    'Municipio': 'SÃO MIGUEL DO ALEIXO',
#    'Estado_Ibge': 28,
#    'Estado': 'SERGIPE',
#    'Sigla_Regiao': 'NE',
#    'Regiao': 'NORDESTE',
#    'VL_PagadorPF': 2361287.07,
#    'QT_PagadorPF': 5732,
#    'VL_PagadorPJ': 151889.17,
#    'QT_PagadorPJ': 67,
#    'VL_RecebedorPF': 1986850.73,
#    'QT_RecebedorPF': 5000,
#    'VL_RecebedorPJ': 24192.84,
#    'QT_RecebedorPJ': 39,
#    'QT_PES_PagadorPF': 520,
#    'QT_PES_PagadorPJ': 10,
#    'QT_PES_RecebedorPF': 607,
#    'QT_PES_RecebedorPJ': 11},
#   {'AnoMes': 202507,
#    'Municipio_Ibge': 3140605,
#    'Municipio': 'MATERLÂNDIA',
#    'Estado_Ibge': 31,
#    'Estado': 'MINAS GERAIS',
#    'Sigla_Regiao': 'SE',
#    'Regiao': 'SUDESTE',
#    'VL_PagadorPF': 12831831.02,
#    'QT_PagadorPF': 56813,
#    'VL_PagadorPJ': 2074782.15,
#    'QT_PagadorPJ': 2288,
#    'VL_RecebedorPF': 13224360.77,
#    'QT_RecebedorPF': 31858,
#    'VL_RecebedorPJ': 1876183.49,
#    'QT_RecebedorPJ': 10690,
#    'QT_PES_PagadorPF': 2180,
#    'QT_PES_PagadorPJ': 80,
#    'QT_PES_RecebedorPF': 2126,
#    'QT_PES_RecebedorPJ': 72},
#   {'AnoMes': 202311,
#    'Municipio_Ibge': 4302402,
#    'Municipio': 'BOM RETIRO DO SUL',
#    'Estado_Ibge': 43,
#    'Estado': 'RIO GRANDE DO SUL',
#    'Sigla_Regiao': 'SU',
#    'Regiao': 'SUL',
#    'VL_PagadorPF': 21970639.78,
#    'QT_PagadorPF': 128566,
#    'VL_PagadorPJ': 13089443.15,
#    'QT_PagadorPJ': 10107,
#    'VL_RecebedorPF': 20504634.94,
#    'QT_RecebedorPF': 70097,
#    'VL_RecebedorPJ': 18966749.21,
#    'QT_RecebedorPJ': 34896,
#    'QT_PES_PagadorPF': 6560,
#    'QT_PES_PagadorPJ': 490,
#    'QT_PES_RecebedorPF': 6070,
#    'QT_PES_RecebedorPJ': 486},
#   {'AnoMes': 202304,
#    'Municipio_Ibge': 5005608,
#    'Municipio': 'MIRANDA',
#    'Estado_Ibge': 50,
#    'Estado': 'MATO GROSSO DO SUL',
#    'Sigla_Regiao': 'CO',
#    'Regiao': 'CENTRO-OESTE',
#    'VL_PagadorPF': 35916706.58,
#    'QT_PagadorPF': 188717,
#    'VL_PagadorPJ': 16587713.46,
#    'QT_PagadorPJ': 14115,
#    'VL_RecebedorPF': 38821070.76,
#    'QT_RecebedorPF': 129249,
#    'VL_RecebedorPJ': 16094595.18,
#    'QT_RecebedorPJ': 33455,
#    'QT_PES_PagadorPF': 10731,
#    'QT_PES_PagadorPJ': 474,
#    'QT_PES_RecebedorPF': 10865,
#    'QT_PES_RecebedorPJ': 465},
#   {'AnoMes': 202207,
#    'Municipio_Ibge': 2410306,
#    'Municipio': 'SERRA CAIADA',
#    'Estado_Ibge': 24,
#    'Estado': 'RIO GRANDE DO NORTE',
#    'Sigla_Regiao': 'NE',
#    'Regiao': 'NORDESTE',
#    'VL_PagadorPF': 7978598.02,
#    'QT_PagadorPF': 43529,
#    'VL_PagadorPJ': 4433754.84,
#    'QT_PagadorPJ': 2488,
#    'VL_RecebedorPF': 7807781.56,
#    'QT_RecebedorPF': 38802,
#    'VL_RecebedorPJ': 3411532.66,
#    'QT_RecebedorPJ': 5717,
#    'QT_PES_PagadorPF': 2709,
#    'QT_PES_PagadorPJ': 97,
#    'QT_PES_RecebedorPF': 2857,
#    'QT_PES_RecebedorPJ': 89},
#   {'AnoMes': 202405,
#    'Municipio_Ibge': 3102308,
#    'Municipio': 'ALVINÓPOLIS',
#    'Estado_Ibge': 31,
#    'Estado': 'MINAS GERAIS',
#    'Sigla_Regiao': 'SE',
#    'Regiao': 'SUDESTE',
#    'VL_PagadorPF': 29261170.57,
#    'QT_PagadorPF': 155182,
#    'VL_PagadorPJ': 9833781.96,
#    'QT_PagadorPJ': 6672,
#    'VL_RecebedorPF': 26755477.09,
#    'QT_RecebedorPF': 91933,
#    'VL_RecebedorPJ': 9806291.45,
#    'QT_RecebedorPJ': 22197,
#    'QT_PES_PagadorPF': 6779,
#    'QT_PES_PagadorPJ': 376,
#    'QT_PES_RecebedorPF': 6507,
#    'QT_PES_RecebedorPJ': 376},
#   {'AnoMes': 202102,
#    'Municipio_Ibge': 3107604,
#    'Municipio': 'BOM JESUS DA PENHA',
#    'Estado_Ibge': 31,
#    'Estado': 'MINAS GERAIS',
#    'Sigla_Regiao': 'SE',
#    'Regiao': 'SUDESTE',
#    'VL_PagadorPF': 865617.81,
#    'QT_PagadorPF': 1321,
#    'VL_PagadorPJ': 31216.86,
#    'QT_PagadorPJ': 49,
#    'VL_RecebedorPF': 561892.23,
#    'QT_RecebedorPF': 1023,
#    'VL_RecebedorPJ': 54064.77,
#    'QT_RecebedorPJ': 53,
#    'QT_PES_PagadorPF': 337,
#    'QT_PES_PagadorPJ': 15,
#    'QT_PES_RecebedorPF': 333,
#    'QT_PES_RecebedorPJ': 20},
#   {'AnoMes': 202603,
#    'Municipio_Ibge': 3140100,
#    'Municipio': 'MARILAC',
#    'Estado_Ibge': 31,
#    'Estado': 'MINAS GERAIS',
#    'Sigla_Regiao': 'SE',
#    'Regiao': 'SUDESTE',
#    'VL_PagadorPF': 14561591.61,
#    'QT_PagadorPF': 82839,
#    'VL_PagadorPJ': 3276039.33,
#    'QT_PagadorPJ': 3800,
#    'VL_RecebedorPF': 15229692.81,
#    'QT_RecebedorPF': 46443,
#    'VL_RecebedorPJ': 3412504.47,
#    'QT_RecebedorPJ': 18244,
#    'QT_PES_PagadorPF': 2615,
#    'QT_PES_PagadorPJ': 134,
#    'QT_PES_RecebedorPF': 2586,
#    'QT_PES_RecebedorPJ': 128},
#   {'AnoMes': 202511,
#    'Municipio_Ibge': 4123824,
#    'Municipio': 'SANTA LÚCIA',
#    'Estado_Ibge': 41,
#    'Estado': 'PARANÁ',
#    'Sigla_Regiao': 'SU',
#    'Regiao': 'SUL',
#    'VL_PagadorPF': 10641446.41,
#    'QT_PagadorPF': 54751,
#    'VL_PagadorPJ': 23983591.1,
#    'QT_PagadorPJ': 5783,
#    'VL_RecebedorPF': 11186317.06,
#    'QT_RecebedorPF': 24921,
#    'VL_RecebedorPJ': 25714206.48,
#    'QT_RecebedorPJ': 14901,
#    'QT_PES_PagadorPF': 2043,
#    'QT_PES_PagadorPJ': 210,
#    'QT_PES_RecebedorPF': 1937,
#    'QT_PES_RecebedorPJ': 200},
#   {'AnoMes': 202412,
#    'Municipio_Ibge': 4311122,
#    'Municipio': 'JAQUIRANA',
#    'Estado_Ibge': 43,
#    'Estado': 'RIO GRANDE DO SUL',
#    'Sigla_Regiao': 'SU',
#    'Regiao': 'SUL',
#    'VL_PagadorPF': 8576732.69,
#    'QT_PagadorPF': 44924,
#    'VL_PagadorPJ': 9545970.36,
#    'QT_PagadorPJ': 3514,
#    'VL_RecebedorPF': 8094240.04,
#    'QT_RecebedorPF': 22400,
#    'VL_RecebedorPJ': 9030111.32,
#    'QT_RecebedorPJ': 11421,
#    'QT_PES_PagadorPF': 1900,
#    'QT_PES_PagadorPJ': 165,
#    'QT_PES_RecebedorPF': 1813,
#    'QT_PES_RecebedorPJ': 152},
#   {'AnoMes': 202311,
#    'Municipio_Ibge': 2804102,
#    'Municipio': 'MOITA BONITA',
#    'Estado_Ibge': 28,
#    'Estado': 'SERGIPE',
#    'Sigla_Regiao': 'NE',
#    'Regiao': 'NORDESTE',
#    'VL_PagadorPF': 25785420.1,
#    'QT_PagadorPF': 92667,
#    'VL_PagadorPJ': 5008044.69,
#    'QT_PagadorPJ': 3678,
#    'VL_RecebedorPF': 25832590.46,
#    'QT_RecebedorPF': 116437,
#    'VL_RecebedorPJ': 4911872.78,
#    'QT_RecebedorPJ': 5641,
#    'QT_PES_PagadorPF': 3933,
#    'QT_PES_PagadorPJ': 189,
#    'QT_PES_RecebedorPF': 3900,
#    'QT_PES_RecebedorPJ': 154},
#   {'AnoMes': 202308,
#    'Municipio_Ibge': 4110904,
#    'Municipio': 'ITAGUAJÉ',
#    'Estado_Ibge': 41,
#    'Estado': 'PARANÁ',
#    'Sigla_Regiao': 'SU',
#    'Regiao': 'SUL',
#    'VL_PagadorPF': 10216203.38,
#    'QT_PagadorPF': 46526,
#    'VL_PagadorPJ': 2632107.36,
#    'QT_PagadorPJ': 3014,
#    'VL_RecebedorPF': 9591091.55,
#    'QT_RecebedorPF': 28366,
#    'VL_RecebedorPJ': 2514032.25,
#    'QT_RecebedorPJ': 7036,
#    'QT_PES_PagadorPF': 2169,
#    'QT_PES_PagadorPJ': 131,
#    'QT_PES_RecebedorPF': 2173,
#    'QT_PES_RecebedorPJ': 132},
#   {'AnoMes': 202101,
#    'Municipio_Ibge': 3527207,
#    'Municipio': 'LORENA',
#    'Estado_Ibge': 35,
#    'Estado': 'SÃO PAULO',
#    'Sigla_Regiao': 'SE',
#    'Regiao': 'SUDESTE',
#    'VL_PagadorPF': 26717254.61,
#    'QT_PagadorPF': 65457,
#    'VL_PagadorPJ': 14614795.24,
#    'QT_PagadorPJ': 6223,
#    'VL_RecebedorPF': 28349248.51,
#    'QT_RecebedorPF': 64714,
#    'VL_RecebedorPJ': 16073662.44,
#    'QT_RecebedorPJ': 6673,
#    'QT_PES_PagadorPF': 13875,
#    'QT_PES_PagadorPJ': 988,
#    'QT_PES_RecebedorPF': 14414,
#    'QT_PES_RecebedorPJ': 1060},
#   {'AnoMes': 202407,
#    'Municipio_Ibge': 3126703,
#    'Municipio': 'FRANCISCO SÁ',
#    'Estado_Ibge': 31,
#    'Estado': 'MINAS GERAIS',
#    'Sigla_Regiao': 'SE',
#    'Regiao': 'SUDESTE',
#    'VL_PagadorPF': 52430347.36,
#    'QT_PagadorPF': 371575,
#    'VL_PagadorPJ': 37509589.28,
#    'QT_PagadorPJ': 18298,
#    'VL_RecebedorPF': 52684131.13,
#    'QT_RecebedorPF': 231146,
#    'VL_RecebedorPJ': 36554811.11,
#    'QT_RecebedorPJ': 59235,
#    'QT_PES_PagadorPF': 11302,
#    'QT_PES_PagadorPJ': 558,
#    'QT_PES_RecebedorPF': 11192,
#    'QT_PES_RecebedorPJ': 528},
#   {'AnoMes': 202503,
#    'Municipio_Ibge': 3114907,
#    'Municipio': 'CASA GRANDE',
#    'Estado_Ibge': 31,
#    'Estado': 'MINAS GERAIS',
#    'Sigla_Regiao': 'SE',
#    'Regiao': 'SUDESTE',
#    'VL_PagadorPF': 6886414.77,
#    'QT_PagadorPF': 18915,
#    'VL_PagadorPJ': 1825923.84,
#    'QT_PagadorPJ': 1092,
#    'VL_RecebedorPF': 7949093.03,
#    'QT_RecebedorPF': 10683,
#    'VL_RecebedorPJ': 1160782.85,
#    'QT_RecebedorPJ': 2403,
#    'QT_PES_PagadorPF': 1075,
#    'QT_PES_PagadorPJ': 62,
#    'QT_PES_RecebedorPF': 997,
#    'QT_PES_RecebedorPJ': 57},
#   {'AnoMes': 202108,
#    'Municipio_Ibge': 4107306,
#    'Municipio': 'DOUTOR CAMARGO',
#    'Estado_Ibge': 41,
#    'Estado': 'PARANÁ',
#    'Sigla_Regiao': 'SU',
#    'Regiao': 'SUL',
#    'VL_PagadorPF': 4927219.1,
#    'QT_PagadorPF': 11731,
#    'VL_PagadorPJ': 6694090.73,
#    'QT_PagadorPJ': 1523,
#    'VL_RecebedorPF': 5139788.76,
#    'QT_RecebedorPF': 10134,
#    'VL_RecebedorPJ': 8794710.61,
#    'QT_RecebedorPJ': 2295,
#    'QT_PES_PagadorPF': 1651,
#    'QT_PES_PagadorPJ': 144,
#    'QT_PES_RecebedorPF': 1569,
#    'QT_PES_RecebedorPJ': 138},
#   {'AnoMes': 202208,
#    'Municipio_Ibge': 4211751,
#    'Municipio': 'OTACÍLIO COSTA',
#    'Estado_Ibge': 42,
#    'Estado': 'SANTA CATARINA',
#    'Sigla_Regiao': 'SU',
#    'Regiao': 'SUL',
#    'VL_PagadorPF': 26328911.77,
#    'QT_PagadorPF': 94221,
#    'VL_PagadorPJ': 35248963.28,
#    'QT_PagadorPJ': 14756,
#    'VL_RecebedorPF': 27446252.79,
#    'QT_RecebedorPF': 63151,
#    'VL_RecebedorPJ': 36924966.31,
#    'QT_RecebedorPJ': 28793,
#    'QT_PES_PagadorPF': 7354,
#    'QT_PES_PagadorPJ': 718,
#    'QT_PES_RecebedorPF': 7090,
#    'QT_PES_RecebedorPJ': 733},
#   {'AnoMes': 202602,
#    'Municipio_Ibge': 2917508,
#    'Municipio': 'JACOBINA',
#    'Estado_Ibge': 29,
#    'Estado': 'BAHIA',
#    'Sigla_Regiao': 'NE',
#    'Regiao': 'NORDESTE',
#    'VL_PagadorPF': 303196457.25,
#    'QT_PagadorPF': 2049113,
#    'VL_PagadorPJ': 170627926.61,
#    'QT_PagadorPJ': 143062,
#    'VL_RecebedorPF': 293626174.0,
#    'QT_RecebedorPF': 1254019,
#    'VL_RecebedorPJ': 114053278.13,
#    'QT_RecebedorPJ': 436468,
#    'QT_PES_PagadorPF': 54499,
#    'QT_PES_PagadorPJ': 3592,
#    'QT_PES_RecebedorPF': 53975,
#    'QT_PES_RecebedorPJ': 3479},
#   {'AnoMes': 202212,
#    'Municipio_Ibge': 4216602,
#    'Municipio': 'SÃO JOSÉ',
#    'Estado_Ibge': 42,
#    'Estado': 'SANTA CATARINA',
#    'Sigla_Regiao': 'SU',
#    'Regiao': 'SUL',
#    'VL_PagadorPF': 852219939.53,
#    'QT_PagadorPF': 2730474,
#    'VL_PagadorPJ': 936247628.14,
#    'QT_PagadorPJ': 378756,
#    'VL_RecebedorPF': 956607849.33,
#    'QT_RecebedorPF': 2219811,
#    'VL_RecebedorPJ': 960415957.27,
#    'QT_RecebedorPJ': 953552,
#    'QT_PES_PagadorPF': 152910,
#    'QT_PES_PagadorPJ': 17232,
#    'QT_PES_RecebedorPF': 152666,
#    'QT_PES_RecebedorPJ': 16070},
#   {'AnoMes': 202508,
#    'Municipio_Ibge': 5204904,
#    'Municipio': 'CAMPOS BELOS',
#    'Estado_Ibge': 52,
#    'Estado': 'GOIÁS',
#    'Sigla_Regiao': 'CO',
#    'Regiao': 'CENTRO-OESTE',
#    'VL_PagadorPF': 102699694.61,
#    'QT_PagadorPF': 560821,
#    'VL_PagadorPJ': 33549469.24,
#    'QT_PagadorPJ': 33083,
#    'VL_RecebedorPF': 94993125.45,
#    'QT_RecebedorPF': 322125,
#    'VL_RecebedorPJ': 36081457.72,
#    'QT_RecebedorPJ': 123203,
#    'QT_PES_PagadorPF': 13513,
#    'QT_PES_PagadorPJ': 1085,
#    'QT_PES_RecebedorPF': 13492,
#    'QT_PES_RecebedorPJ': 930},
#   {'AnoMes': 202604,
#    'Municipio_Ibge': 2700508,
#    'Municipio': 'BARRA DE SANTO ANTÔNIO',
#    'Estado_Ibge': 27,
#    'Estado': 'ALAGOAS',
#    'Sigla_Regiao': 'NE',
#    'Regiao': 'NORDESTE',
#    'VL_PagadorPF': 50782317.73,
#    'QT_PagadorPF': 463143,
#    'VL_PagadorPJ': 11315625.02,
#    'QT_PagadorPJ': 15582,
#    'VL_RecebedorPF': 50451636.54,
#    'QT_RecebedorPF': 278971,
#    'VL_RecebedorPJ': 11094555.46,
#    'QT_RecebedorPJ': 56292,
#    'QT_PES_PagadorPF': 9883,
#    'QT_PES_PagadorPJ': 358,
#    'QT_PES_RecebedorPF': 9721,
#    'QT_PES_RecebedorPJ': 337},
#   {'AnoMes': 202606,
#    'Municipio_Ibge': 2705101,
#    'Municipio': 'MATRIZ DE CAMARAGIBE',
#    'Estado_Ibge': 27,
#    'Estado': 'ALAGOAS',
#    'Sigla_Regiao': 'NE',
#    'Regiao': 'NORDESTE',
#    'VL_PagadorPF': 11962970.66,
#    'QT_PagadorPF': 89350,
#    'VL_PagadorPJ': 2948297.82,
#    'QT_PagadorPJ': 3315,
#    'VL_RecebedorPF': 10907083.85,
#    'QT_RecebedorPF': 55080,
#    'VL_RecebedorPJ': 1713945.66,
#    'QT_RecebedorPJ': 12007,
#    'QT_PES_PagadorPF': 12265,
#    'QT_PES_PagadorPJ': 323,
#    'QT_PES_RecebedorPF': 10619,
#    'QT_PES_RecebedorPJ': 298},
#   {'AnoMes': 202207,
#    'Municipio_Ibge': 2108256,
#    'Municipio': 'PEDRO DO ROSÁRIO',
#    'Estado_Ibge': 21,
#    'Estado': 'MARANHÃO',
#    'Sigla_Regiao': 'NE',
#    'Regiao': 'NORDESTE',
#    'VL_PagadorPF': 11527889.68,
#    'QT_PagadorPF': 70333,
#    'VL_PagadorPJ': 1253213.11,
#    'QT_PagadorPJ': 1221,
#    'VL_RecebedorPF': 11365270.76,
#    'QT_RecebedorPF': 54656,
#    'VL_RecebedorPJ': 861833.73,
#    'QT_RecebedorPJ': 3327,
#    'QT_PES_PagadorPF': 4193,
#    'QT_PES_PagadorPJ': 74,
#    'QT_PES_RecebedorPF': 4412,
#    'QT_PES_RecebedorPJ': 57},
#   {'AnoMes': 202402,
#    'Municipio_Ibge': 2203800,
#    'Municipio': 'FLORES DO PIAUÍ',
#    'Estado_Ibge': 22,
#    'Estado': 'PIAUÍ',
#    'Sigla_Regiao': 'NE',
#    'Regiao': 'NORDESTE',
#    'VL_PagadorPF': 7068317.09,
#    'QT_PagadorPF': 59192,
#    'VL_PagadorPJ': 590612.23,
#    'QT_PagadorPJ': 998,
#    'VL_RecebedorPF': 7008596.93,
#    'QT_RecebedorPF': 35446,
#    'VL_RecebedorPJ': 467387.28,
#    'QT_RecebedorPJ': 4679,
#    'QT_PES_PagadorPF': 1953,
#    'QT_PES_PagadorPJ': 46,
#    'QT_PES_RecebedorPF': 1912,
#    'QT_PES_RecebedorPJ': 48},
#   {'AnoMes': 202505,
#    'Municipio_Ibge': 2202091,
#    'Municipio': 'CALDEIRÃO GRANDE DO PIAUÍ',
#    'Estado_Ibge': 22,
#    'Estado': 'PIAUÍ',
#    'Sigla_Regiao': 'NE',
#    'Regiao': 'NORDESTE',
#    'VL_PagadorPF': 11104225.96,
#    'QT_PagadorPF': 79566,
#    'VL_PagadorPJ': 13060925.36,
#    'QT_PagadorPJ': 1721,
#    'VL_RecebedorPF': 10240216.71,
#    'QT_RecebedorPF': 49750,
#    'VL_RecebedorPJ': 13380687.34,
#    'QT_RecebedorPJ': 4160,
#    'QT_PES_PagadorPF': 2528,
#    'QT_PES_PagadorPJ': 61,
#    'QT_PES_RecebedorPF': 2400,
#    'QT_PES_RecebedorPJ': 51},
#   {'AnoMes': 202605,
#    'Municipio_Ibge': 1400050,
#    'Municipio': 'ALTO ALEGRE',
#    'Estado_Ibge': 14,
#    'Estado': 'RORAIMA',
#    'Sigla_Regiao': 'NO',
#    'Regiao': 'NORTE',
#    'VL_PagadorPF': 49713494.59,
#    'QT_PagadorPF': 328286,
#    'VL_PagadorPJ': 11660163.51,
#    'QT_PagadorPJ': 16863,
#    'VL_RecebedorPF': 45496566.03,
#    'QT_RecebedorPF': 179342,
#    'VL_RecebedorPJ': 10016200.62,
#    'QT_RecebedorPJ': 68692,
#    'QT_PES_PagadorPF': 6947,
#    'QT_PES_PagadorPJ': 234,
#    'QT_PES_RecebedorPF': 6747,
#    'QT_PES_RecebedorPJ': 232},
#   {'AnoMes': 202304,
#    'Municipio_Ibge': 3509106,
#    'Municipio': 'CAIUÁ',
#    'Estado_Ibge': 35,
#    'Estado': 'SÃO PAULO',
#    'Sigla_Regiao': 'SE',
#    'Regiao': 'SUDESTE',
#    'VL_PagadorPF': 5706658.41,
#    'QT_PagadorPF': 28821,
#    'VL_PagadorPJ': 782048.48,
#    'QT_PagadorPJ': 1712,
#    'VL_RecebedorPF': 5401055.52,
#    'QT_RecebedorPF': 18305,
#    'VL_RecebedorPJ': 877641.24,
#    'QT_RecebedorPJ': 3208,
#    'QT_PES_PagadorPF': 1707,
#    'QT_PES_PagadorPJ': 66,
#    'QT_PES_RecebedorPF': 1700,
#    'QT_PES_RecebedorPJ': 70},
#   {'AnoMes': 202507,
#    'Municipio_Ibge': 3513306,
#    'Municipio': 'CRUZÁLIA',
#    'Estado_Ibge': 35,
#    'Estado': 'SÃO PAULO',
#    'Sigla_Regiao': 'SE',
#    'Regiao': 'SUDESTE',
#    'VL_PagadorPF': 6264081.6,
#    'QT_PagadorPF': 37719,
#    'VL_PagadorPJ': 14310023.3,
#    'QT_PagadorPJ': 3234,
#    'VL_RecebedorPF': 6181359.24,
#    'QT_RecebedorPF': 20080,
#    'VL_RecebedorPJ': 13623140.23,
#    'QT_RecebedorPJ': 5557,
#    'QT_PES_PagadorPF': 1311,
#    'QT_PES_PagadorPJ': 109,
#    'QT_PES_RecebedorPF': 1247,
#    'QT_PES_RecebedorPJ': 116},
#   {'AnoMes': 202512,
#    'Municipio_Ibge': 3555109,
#    'Municipio': 'TUPI PAULISTA',
#    'Estado_Ibge': 35,
#    'Estado': 'SÃO PAULO',
#    'Sigla_Regiao': 'SE',
#    'Regiao': 'SUDESTE',
#    'VL_PagadorPF': 78876813.7,
#    'QT_PagadorPF': 305519,
#    'VL_PagadorPJ': 39727799.15,
#    'QT_PagadorPJ': 26918,
#    'VL_RecebedorPF': 75031905.98,
#    'QT_RecebedorPF': 172657,
#    'VL_RecebedorPJ': 43397127.37,
#    'QT_RecebedorPJ': 78888,
#    'QT_PES_PagadorPF': 8850,
#    'QT_PES_PagadorPJ': 767,
#    'QT_PES_RecebedorPF': 8592,
#    'QT_PES_RecebedorPJ': 727},
#   {'AnoMes': 202103,
#    'Municipio_Ibge': 5222005,
#    'Municipio': 'VIANÓPOLIS',
#    'Estado_Ibge': 52,
#    'Estado': 'GOIÁS',
#    'Sigla_Regiao': 'CO',
#    'Regiao': 'CENTRO-OESTE',
#    'VL_PagadorPF': 10621282.79,
#    'QT_PagadorPF': 15134,
#    'VL_PagadorPJ': 6127636.8,
#    'QT_PagadorPJ': 2285,
#    'VL_RecebedorPF': 11926356.75,
#    'QT_RecebedorPF': 13691,
#    'VL_RecebedorPJ': 4473066.29,
#    'QT_RecebedorPJ': 3164,
#    'QT_PES_PagadorPF': 2273,
#    'QT_PES_PagadorPJ': 265,
#    'QT_PES_RecebedorPF': 2532,
#    'QT_PES_RecebedorPJ': 268},
#   {'AnoMes': 202603,
#    'Municipio_Ibge': 2914109,
#    'Municipio': 'IPUPIARA',
#    'Estado_Ibge': 29,
#    'Estado': 'BAHIA',
#    'Sigla_Regiao': 'NE',
#    'Regiao': 'NORDESTE',
#    'VL_PagadorPF': 33931119.41,
#    'QT_PagadorPF': 170167,
#    'VL_PagadorPJ': 8008801.7,
#    'QT_PagadorPJ': 7709,
#    'VL_RecebedorPF': 30808465.83,
#    'QT_RecebedorPF': 110588,
#    'VL_RecebedorPJ': 9524134.32,
#    'QT_RecebedorPJ': 36800,
#    'QT_PES_PagadorPF': 4957,
#    'QT_PES_PagadorPJ': 285,
#    'QT_PES_RecebedorPF': 4649,
#    'QT_PES_RecebedorPJ': 268},
#   {'AnoMes': 202109,
#    'Municipio_Ibge': 4202859,
#    'Municipio': 'BRAÇO DO TROMBUDO',
#    'Estado_Ibge': 42,
#    'Estado': 'SANTA CATARINA',
#    'Sigla_Regiao': 'SU',
#    'Regiao': 'SUL',
#    'VL_PagadorPF': 2730010.09,
#    'QT_PagadorPF': 5502,
#    'VL_PagadorPJ': 2061757.88,
#    'QT_PagadorPJ': 829,
#    'VL_RecebedorPF': 2365615.0,
#    'QT_RecebedorPF': 3890,
#    'VL_RecebedorPJ': 3574183.87,
#    'QT_RecebedorPJ': 1339,
#    'QT_PES_PagadorPF': 944,
#    'QT_PES_PagadorPJ': 107,
#    'QT_PES_RecebedorPF': 779,
#    'QT_PES_RecebedorPJ': 100},
#   {'AnoMes': 202402,
#    'Municipio_Ibge': 3116902,
#    'Municipio': 'COMENDADOR GOMES',
#    'Estado_Ibge': 31,
#    'Estado': 'MINAS GERAIS',
#    'Sigla_Regiao': 'SE',
#    'Regiao': 'SUDESTE',
#    'VL_PagadorPF': 6059695.08,
#    'QT_PagadorPF': 29679,
#    'VL_PagadorPJ': 4540918.16,
#    'QT_PagadorPJ': 2337,
#    'VL_RecebedorPF': 6904710.1,
#    'QT_RecebedorPF': 17918,
#    'VL_RecebedorPJ': 3670900.25,
#    'QT_RecebedorPJ': 5600,
#    'QT_PES_PagadorPF': 1318,
#    'QT_PES_PagadorPJ': 112,
#    'QT_PES_RecebedorPF': 1293,
#    'QT_PES_RecebedorPJ': 100},
#   {'AnoMes': 202511,
#    'Municipio_Ibge': 2211506,
#    'Municipio': 'VERA MENDES',
#    'Estado_Ibge': 22,
#    'Estado': 'PIAUÍ',
#    'Sigla_Regiao': 'NE',
#    'Regiao': 'NORDESTE',
#    'VL_PagadorPF': 7637088.59,
#    'QT_PagadorPF': 56422,
#    'VL_PagadorPJ': 830982.93,
#    'QT_PagadorPJ': 1317,
#    'VL_RecebedorPF': 7106288.87,
#    'QT_RecebedorPF': 38809,
#    'VL_RecebedorPJ': 735128.91,
#    'QT_RecebedorPJ': 4520,
#    'QT_PES_PagadorPF': 1656,
#    'QT_PES_PagadorPJ': 42,
#    'QT_PES_RecebedorPF': 1620,
#    'QT_PES_RecebedorPJ': 38},
#   {'AnoMes': 202408,
#    'Municipio_Ibge': 1506583,
#    'Municipio': 'SANTA MARIA DAS BARREIRAS',
#    'Estado_Ibge': 15,
#    'Estado': 'PARÁ',
#    'Sigla_Regiao': 'NO',
#    'Regiao': 'NORTE',
#    'VL_PagadorPF': 44511652.68,
#    'QT_PagadorPF': 201855,
#    'VL_PagadorPJ': 25986607.57,
#    'QT_PagadorPJ': 15306,
#    'VL_RecebedorPF': 42273131.17,
#    'QT_RecebedorPF': 116864,
#    'VL_RecebedorPJ': 29983582.96,
#    'QT_RecebedorPJ': 57572,
#    'QT_PES_PagadorPF': 5857,
#    'QT_PES_PagadorPJ': 456,
#    'QT_PES_RecebedorPF': 5734,
#    'QT_PES_RecebedorPJ': 408},
#   {'AnoMes': 202503,
#    'Municipio_Ibge': 5107941,
#    'Municipio': 'TABAPORÃ',
#    'Estado_Ibge': 51,
#    'Estado': 'MATO GROSSO',
#    'Sigla_Regiao': 'CO',
#    'Regiao': 'CENTRO-OESTE',
#    'VL_PagadorPF': 58971846.82,
#    'QT_PagadorPF': 179240,
#    'VL_PagadorPJ': 24953299.6,
#    'QT_PagadorPJ': 15598,
#    'VL_RecebedorPF': 78169582.94,
#    'QT_RecebedorPF': 94770,
#    'VL_RecebedorPJ': 23758172.16,
#    'QT_RecebedorPJ': 42636,
#    'QT_PES_PagadorPF': 6179,
#    'QT_PES_PagadorPJ': 594,
#    'QT_PES_RecebedorPF': 5925,
#    'QT_PES_RecebedorPJ': 563},
#   {'AnoMes': 202204,
#    'Municipio_Ibge': 2806107,
#    'Municipio': 'ROSÁRIO DO CATETE',
#    'Estado_Ibge': 28,
#    'Estado': 'SERGIPE',
#    'Sigla_Regiao': 'NE',
#    'Regiao': 'NORDESTE',
#    'VL_PagadorPF': 8204740.23,
#    'QT_PagadorPF': 50155,
#    'VL_PagadorPJ': 1925970.96,
#    'QT_PagadorPJ': 1282,
#    'VL_RecebedorPF': 8517891.91,
#    'QT_RecebedorPF': 40940,
#    'VL_RecebedorPJ': 1567940.66,
#    'QT_RecebedorPJ': 3160,
#    'QT_PES_PagadorPF': 3216,
#    'QT_PES_PagadorPJ': 78,
#    'QT_PES_RecebedorPF': 3457,
#    'QT_PES_RecebedorPJ': 73},
#   {'AnoMes': 202209,
#    'Municipio_Ibge': 4209458,
#    'Municipio': 'LAJEADO GRANDE',
#    'Estado_Ibge': 42,
#    'Estado': 'SANTA CATARINA',
#    'Sigla_Regiao': 'SU',
#    'Regiao': 'SUL',
#    'VL_PagadorPF': 1843104.0,
#    'QT_PagadorPF': 3873,
#    'VL_PagadorPJ': 512229.59,
#    'QT_PagadorPJ': 370,
#    'VL_RecebedorPF': 1453331.6,
#    'QT_RecebedorPF': 2338,
#    'VL_RecebedorPJ': 791973.89,
#    'QT_RecebedorPJ': 902,
#    'QT_PES_PagadorPF': 444,
#    'QT_PES_PagadorPJ': 47,
#    'QT_PES_RecebedorPF': 397,
#    'QT_PES_RecebedorPJ': 48},
#   {'AnoMes': 202401,
#    'Municipio_Ibge': 3154101,
#    'Municipio': 'RECREIO',
#    'Estado_Ibge': 31,
#    'Estado': 'MINAS GERAIS',
#    'Sigla_Regiao': 'SE',
#    'Regiao': 'SUDESTE',
#    'VL_PagadorPF': 13065386.42,
#    'QT_PagadorPF': 85385,
#    'VL_PagadorPJ': 3235467.39,
#    'QT_PagadorPJ': 2540,
#    'VL_RecebedorPF': 12711294.08,
#    'QT_RecebedorPF': 55444,
#    'VL_RecebedorPJ': 2195587.25,
#    'QT_RecebedorPJ': 9246,
#    'QT_PES_PagadorPF': 3843,
#    'QT_PES_PagadorPJ': 172,
#    'QT_PES_RecebedorPF': 3822,
#    'QT_PES_RecebedorPJ': 179},
#   {'AnoMes': 202412,
#    'Municipio_Ibge': 4217808,
#    'Municipio': 'TAIÓ',
#    'Estado_Ibge': 42,
#    'Estado': 'SANTA CATARINA',
#    'Sigla_Regiao': 'SU',
#    'Regiao': 'SUL',
#    'VL_PagadorPF': 59099890.71,
#    'QT_PagadorPF': 234456,
#    'VL_PagadorPJ': 93997118.71,
#    'QT_PagadorPJ': 32089,
#    'VL_RecebedorPF': 57261918.39,
#    'QT_RecebedorPF': 115222,
#    'VL_RecebedorPJ': 94680230.94,
#    'QT_RecebedorPJ': 91026,
#    'QT_PES_PagadorPF': 10009,
#    'QT_PES_PagadorPJ': 1483,
#    'QT_PES_RecebedorPF': 9637,
#    'QT_PES_RecebedorPJ': 1427},
#   {'AnoMes': 202510,
#    'Municipio_Ibge': 3104502,
#    'Municipio': 'ARINOS',
#    'Estado_Ibge': 31,
#    'Estado': 'MINAS GERAIS',
#    'Sigla_Regiao': 'SE',
#    'Regiao': 'SUDESTE',
#    'VL_PagadorPF': 62496270.59,
#    'QT_PagadorPF': 414986,
#    'VL_PagadorPJ': 59847369.4,
#    'QT_PagadorPJ': 29559,
#    'VL_RecebedorPF': 63484065.58,
#    'QT_RecebedorPF': 228697,
#    'VL_RecebedorPJ': 67477682.29,
#    'QT_RecebedorPJ': 94667,
#    'QT_PES_PagadorPF': 10990,
#    'QT_PES_PagadorPJ': 709,
#    'QT_PES_RecebedorPF': 10722,
#    'QT_PES_RecebedorPJ': 712},
#   {'AnoMes': 202209,
#    'Municipio_Ibge': 2514453,
#    'Municipio': 'SÃO JOSÉ DOS RAMOS',
#    'Estado_Ibge': 25,
#    'Estado': 'PARAÍBA',
#    'Sigla_Regiao': 'NE',
#    'Regiao': 'NORDESTE',
#    'VL_PagadorPF': 3543077.01,
#    'QT_PagadorPF': 21796,
#    'VL_PagadorPJ': 758985.62,
#    'QT_PagadorPJ': 696,
#    'VL_RecebedorPF': 3830725.91,
#    'QT_RecebedorPF': 17594,
#    'VL_RecebedorPJ': 227472.22,
#    'QT_RecebedorPJ': 1549,
#    'QT_PES_PagadorPF': 1309,
#    'QT_PES_PagadorPJ': 31,
#    'QT_PES_RecebedorPF': 1439,
#    'QT_PES_RecebedorPJ': 24},
#   {'AnoMes': 202303,
#    'Municipio_Ibge': 4115101,
#    'Municipio': 'MARILUZ',
#    'Estado_Ibge': 41,
#    'Estado': 'PARANÁ',
#    'Sigla_Regiao': 'SU',
#    'Regiao': 'SUL',
#    'VL_PagadorPF': 17149100.26,
#    'QT_PagadorPF': 58667,
#    'VL_PagadorPJ': 11402631.23,
#    'QT_PagadorPJ': 5190,
#    'VL_RecebedorPF': 23597056.49,
#    'QT_RecebedorPF': 39824,
#    'VL_RecebedorPJ': 10207990.82,
#    'QT_RecebedorPJ': 12873,
#    'QT_PES_PagadorPF': 3916,
#    'QT_PES_PagadorPJ': 231,
#    'QT_PES_RecebedorPF': 3932,
#    'QT_PES_RecebedorPJ': 245},
#   {'AnoMes': 202203,
#    'Municipio_Ibge': 3532306,
#    'Municipio': 'NATIVIDADE DA SERRA',
#    'Estado_Ibge': 35,
#    'Estado': 'SÃO PAULO',
#    'Sigla_Regiao': 'SE',
#    'Regiao': 'SUDESTE',
#    'VL_PagadorPF': 4821334.56,
#    'QT_PagadorPF': 20237,
#    'VL_PagadorPJ': 2541037.69,
#    'QT_PagadorPJ': 1987,
#    'VL_RecebedorPF': 5756124.29,
#    'QT_RecebedorPF': 17797,
#    'VL_RecebedorPJ': 1683110.95,
#    'QT_RecebedorPJ': 3878,
#    'QT_PES_PagadorPF': 1889,
#    'QT_PES_PagadorPJ': 132,
#    'QT_PES_RecebedorPF': 1936,
#    'QT_PES_RecebedorPJ': 127},
#   {'AnoMes': 202209,
#    'Municipio_Ibge': 5208400,
#    'Municipio': 'GOIANÁPOLIS',
#    'Estado_Ibge': 52,
#    'Estado': 'GOIÁS',
#    'Sigla_Regiao': 'CO',
#    'Regiao': 'CENTRO-OESTE',
#    'VL_PagadorPF': 33202000.22,
#    'QT_PagadorPF': 87496,
#    'VL_PagadorPJ': 20742324.83,
#    'QT_PagadorPJ': 7332,
#    'VL_RecebedorPF': 33472257.27,
#    'QT_RecebedorPF': 73675,
#    'VL_RecebedorPJ': 24757618.25,
#    'QT_RecebedorPJ': 13621,
#    'QT_PES_PagadorPF': 5142,
#    'QT_PES_PagadorPJ': 317,
#    'QT_PES_RecebedorPF': 5326,
#    'QT_PES_RecebedorPJ': 303},
#   {'AnoMes': 202109,
#    'Municipio_Ibge': 4304614,
#    'Municipio': 'CANUDOS DO VALE',
#    'Estado_Ibge': 43,
#    'Estado': 'RIO GRANDE DO SUL',
#    'Sigla_Regiao': 'SU',
#    'Regiao': 'SUL',
#    'VL_PagadorPF': 324465.34,
#    'QT_PagadorPF': 905,
#    'VL_PagadorPJ': 62587.09,
#    'QT_PagadorPJ': 82,
#    'VL_RecebedorPF': 305515.55,
#    'QT_RecebedorPF': 822,
#    'VL_RecebedorPJ': 80333.74,
#    'QT_RecebedorPJ': 60,
#    'QT_PES_PagadorPF': 190,
#    'QT_PES_PagadorPJ': 13,
#    'QT_PES_RecebedorPF': 161,
#    'QT_PES_RecebedorPJ': 17},
#   {'AnoMes': 202109,
#    'Municipio_Ibge': 3140001,
#    'Municipio': 'MARIANA',
#    'Estado_Ibge': 31,
#    'Estado': 'MINAS GERAIS',
#    'Sigla_Regiao': 'SE',
#    'Regiao': 'SUDESTE',
#    'VL_PagadorPF': 60517776.77,
#    'QT_PagadorPF': 179750,
#    'VL_PagadorPJ': 31546760.04,
#    'QT_PagadorPJ': 17755,
#    'VL_RecebedorPF': 56279437.67,
#    'QT_RecebedorPF': 155412,
#    'VL_RecebedorPJ': 26997002.2,
#    'QT_RecebedorPJ': 27886,
#    'QT_PES_PagadorPF': 20823,
#    'QT_PES_PagadorPJ': 1392,
#    'QT_PES_RecebedorPF': 20418,
#    'QT_PES_RecebedorPJ': 1399},
#   {'AnoMes': 202503,
#    'Municipio_Ibge': 2205565,
#    'Municipio': 'LAGOA DO BARRO DO PIAUÍ',
#    'Estado_Ibge': 22,
#    'Estado': 'PIAUÍ',
#    'Sigla_Regiao': 'NE',
#    'Regiao': 'NORDESTE',
#    'VL_PagadorPF': 12733515.12,
#    'QT_PagadorPF': 86962,
#    'VL_PagadorPJ': 2372020.52,
#    'QT_PagadorPJ': 3444,
#    'VL_RecebedorPF': 11623337.18,
#    'QT_RecebedorPF': 49797,
#    'VL_RecebedorPJ': 4250299.93,
#    'QT_RecebedorPJ': 13673,
#    'QT_PES_PagadorPF': 2713,
#    'QT_PES_PagadorPJ': 99,
#    'QT_PES_RecebedorPF': 2650,
#    'QT_PES_RecebedorPJ': 102},
#   {'AnoMes': 202606,
#    'Municipio_Ibge': 3506300,
#    'Municipio': 'BERNARDINO DE CAMPOS',
#    'Estado_Ibge': 35,
#    'Estado': 'SÃO PAULO',
#    'Sigla_Regiao': 'SE',
#    'Regiao': 'SUDESTE',
#    'VL_PagadorPF': 5552242.82,
#    'QT_PagadorPF': 30475,
#    'VL_PagadorPJ': 7528410.72,
#    'QT_PagadorPJ': 3095,
#    'VL_RecebedorPF': 5218950.88,
#    'QT_RecebedorPF': 14648,
#    'VL_RecebedorPJ': 9666490.48,
#    'QT_RecebedorPJ': 7301,
#    'QT_PES_PagadorPF': 4798,
#    'QT_PES_PagadorPJ': 370,
#    'QT_PES_RecebedorPF': 3776,
#    'QT_PES_RecebedorPJ': 384},
#   {'AnoMes': 202303,
#    'Municipio_Ibge': 2701803,
#    'Municipio': 'CARNEIROS',
#    'Estado_Ibge': 27,
#    'Estado': 'ALAGOAS',
#    'Sigla_Regiao': 'NE',
#    'Regiao': 'NORDESTE',
#    'VL_PagadorPF': 6718049.88,
#    'QT_PagadorPF': 41954,
#    'VL_PagadorPJ': 1072515.89,
#    'QT_PagadorPJ': 914,
#    'VL_RecebedorPF': 6834032.56,
#    'QT_RecebedorPF': 29079,
#    'VL_RecebedorPJ': 975417.37,
#    'QT_RecebedorPJ': 2556,
#    'QT_PES_PagadorPF': 2703,
#    'QT_PES_PagadorPJ': 59,
#    'QT_PES_RecebedorPF': 2866,
#    'QT_PES_RecebedorPJ': 55},
#   {'AnoMes': 202305,
#    'Municipio_Ibge': 3530003,
#    'Municipio': 'MIRA ESTRELA',
#    'Estado_Ibge': 35,
#    'Estado': 'SÃO PAULO',
#    'Sigla_Regiao': 'SE',
#    'Regiao': 'SUDESTE',
#    'VL_PagadorPF': 5523633.77,
#    'QT_PagadorPF': 22121,
#    'VL_PagadorPJ': 3758556.17,
#    'QT_PagadorPJ': 2034,
#    'VL_RecebedorPF': 5526016.02,
#    'QT_RecebedorPF': 15673,
#    'VL_RecebedorPJ': 3233802.71,
#    'QT_RecebedorPJ': 4335,
#    'QT_PES_PagadorPF': 1331,
#    'QT_PES_PagadorPJ': 101,
#    'QT_PES_RecebedorPF': 1383,
#    'QT_PES_RecebedorPJ': 100},
#   {'AnoMes': 202604,
#    'Municipio_Ibge': 3204955,
#    'Municipio': 'SÃO ROQUE DO CANAÃ',
#    'Estado_Ibge': 32,
#    'Estado': 'ESPÍRITO SANTO',
#    'Sigla_Regiao': 'SE',
#    'Regiao': 'SUDESTE',
#    'VL_PagadorPF': 41792597.54,
#    'QT_PagadorPF': 183884,
#    'VL_PagadorPJ': 24121576.51,
#    'QT_PagadorPJ': 8108,
#    'VL_RecebedorPF': 44158422.79,
#    'QT_RecebedorPF': 96391,
#    'VL_RecebedorPJ': 15694830.63,
#    'QT_RecebedorPJ': 40859,
#    'QT_PES_PagadorPF': 5814,
#    'QT_PES_PagadorPJ': 430,
#    'QT_PES_RecebedorPF': 5608,
#    'QT_PES_RecebedorPJ': 411},
#   {'AnoMes': 202401,
#    'Municipio_Ibge': 4119004,
#    'Municipio': "PÉROLA D'OESTE",
#    'Estado_Ibge': 41,
#    'Estado': 'PARANÁ',
#    'Sigla_Regiao': 'SU',
#    'Regiao': 'SUL',
#    'VL_PagadorPF': 11772631.57,
#    'QT_PagadorPF': 45103,
#    'VL_PagadorPJ': 10506658.12,
#    'QT_PagadorPJ': 6467,
#    'VL_RecebedorPF': 10420247.64,
#    'QT_RecebedorPF': 20895,
#    'VL_RecebedorPJ': 9056203.28,
#    'QT_RecebedorPJ': 12688,
#    'QT_PES_PagadorPF': 2840,
#    'QT_PES_PagadorPJ': 290,
#    'QT_PES_RecebedorPF': 2470,
#    'QT_PES_RecebedorPJ': 279},
#   {'AnoMes': 202408,
#    'Municipio_Ibge': 4101002,
#    'Municipio': 'AMPÉRE',
#    'Estado_Ibge': 41,
#    'Estado': 'PARANÁ',
#    'Sigla_Regiao': 'SU',
#    'Regiao': 'SUL',
#    'VL_PagadorPF': 55855100.17,
#    'QT_PagadorPF': 246949,
#    'VL_PagadorPJ': 60215206.49,
#    'QT_PagadorPJ': 33549,
#    'VL_RecebedorPF': 53402848.36,
#    'QT_RecebedorPF': 127505,
#    'VL_RecebedorPJ': 66774101.83,
#    'QT_RecebedorPJ': 101742,
#    'QT_PES_PagadorPF': 9797,
#    'QT_PES_PagadorPJ': 1178,
#    'QT_PES_RecebedorPF': 9462,
#    'QT_PES_RecebedorPJ': 1153},
#   {'AnoMes': 202308,
#    'Municipio_Ibge': 2916609,
#    'Municipio': 'ITAPITANGA',
#    'Estado_Ibge': 29,
#    'Estado': 'BAHIA',
#    'Sigla_Regiao': 'NE',
#    'Regiao': 'NORDESTE',
#    'VL_PagadorPF': 10265394.98,
#    'QT_PagadorPF': 77622,
#    'VL_PagadorPJ': 1169909.96,
#    'QT_PagadorPJ': 1421,
#    'VL_RecebedorPF': 9992204.58,
#    'QT_RecebedorPF': 50494,
#    'VL_RecebedorPJ': 1243849.81,
#    'QT_RecebedorPJ': 5746,
#    'QT_PES_PagadorPF': 3244,
#    'QT_PES_PagadorPJ': 92,
#    'QT_PES_RecebedorPF': 3291,
#    'QT_PES_RecebedorPJ': 87},
# ...
#    'QT_PES_RecebedorPJ': 77},
#   {'AnoMes': 202511,
#    'Municipio_Ibge': 5213806,
#    'Municipio': 'MORRINHOS',
#    'Estado_Ibge': 52,
#    'Estado': 'GOIÁS',
#    'Sigla_Regiao': 'CO',
#    'Regiao': 'CENTRO-OESTE',
#    'VL_PagadorPF': 263031494.96,
#    'QT_PagadorPF': 1177102,
#    'VL_PagadorPJ': 183698812.39,
#    'QT_PagadorPJ': 108666,
#    'VL_RecebedorPF': 253619302.45,
#    'QT_RecebedorPF': 681527,
#    'VL_RecebedorPJ': 205401367.26,
#    'QT_RecebedorPJ': 335664,
#    'QT_PES_PagadorPF': 30930,
#    'QT_PES_PagadorPJ': 2779,
#    'QT_PES_RecebedorPF': 31008,
#    'QT_PES_RecebedorPJ': 2578},
#   {'AnoMes': 202411,
#    'Municipio_Ibge': 5106851,
#    'Municipio': 'PORTO ESTRELA',
#    'Estado_Ibge': 51,
#    'Estado': 'MATO GROSSO',
#    'Sigla_Regiao': 'CO',
#    'Regiao': 'CENTRO-OESTE',
#    'VL_PagadorPF': 8989895.32,
#    'QT_PagadorPF': 49247,
#    'VL_PagadorPJ': 3697118.48,
#    'QT_PagadorPJ': 2493,
#    'VL_RecebedorPF': 9321261.11,
#    'QT_RecebedorPF': 27043,
#    'VL_RecebedorPJ': 2041660.68,
#    'QT_RecebedorPJ': 5317,
#    'QT_PES_PagadorPF': 1870,
#    'QT_PES_PagadorPJ': 94,
#    'QT_PES_RecebedorPF': 1830,
#    'QT_PES_RecebedorPJ': 76},
#   {'AnoMes': 202012,
#    'Municipio_Ibge': 4112702,
#    'Municipio': 'JATAIZINHO',
#    'Estado_Ibge': 41,
#    'Estado': 'PARANÁ',
#    'Sigla_Regiao': 'SU',
#    'Regiao': 'SUL',
#    'VL_PagadorPF': 1259958.27,
#    'QT_PagadorPF': 3210,
#    'VL_PagadorPJ': 721743.54,
#    'QT_PagadorPJ': 197,
#    'VL_RecebedorPF': 1504485.7,
#    'QT_RecebedorPF': 3268,
#    'VL_RecebedorPJ': 716075.46,
#    'QT_RecebedorPJ': 276,
#    'QT_PES_PagadorPF': 782,
#    'QT_PES_PagadorPJ': 53,
#    'QT_PES_RecebedorPF': 844,
#    'QT_PES_RecebedorPJ': 73},
#   {'AnoMes': 202107,
#    'Municipio_Ibge': 4307815,
#    'Municipio': 'ESTRELA VELHA',
#    'Estado_Ibge': 43,
#    'Estado': 'RIO GRANDE DO SUL',
#    'Sigla_Regiao': 'SU',
#    'Regiao': 'SUL',
#    'VL_PagadorPF': 1308907.61,
#    'QT_PagadorPF': 2679,
#    'VL_PagadorPJ': 936156.82,
#    'QT_PagadorPJ': 198,
#    'VL_RecebedorPF': 2602144.31,
#    'QT_RecebedorPF': 1852,
#    'VL_RecebedorPJ': 778072.23,
#    'QT_RecebedorPJ': 252,
#    'QT_PES_PagadorPF': 486,
#    'QT_PES_PagadorPJ': 26,
#    'QT_PES_RecebedorPF': 379,
#    'QT_PES_RecebedorPJ': 35},
#   {'AnoMes': 202306,
#    'Municipio_Ibge': 1600204,
#    'Municipio': 'CALÇOENE',
#    'Estado_Ibge': 16,
#    'Estado': 'AMAPÁ',
#    'Sigla_Regiao': 'NO',
#    'Regiao': 'NORTE',
#    'VL_PagadorPF': 21322340.97,
#    'QT_PagadorPF': 117436,
#    'VL_PagadorPJ': 12370566.73,
#    'QT_PagadorPJ': 6871,
#    'VL_RecebedorPF': 20691900.89,
#    'QT_RecebedorPF': 87099,
#    'VL_RecebedorPJ': 11871665.96,
#    'QT_RecebedorPJ': 12503,
#    'QT_PES_PagadorPF': 4300,
#    'QT_PES_PagadorPJ': 145,
#    'QT_PES_RecebedorPF': 4240,
#    'QT_PES_RecebedorPJ': 152},
#   {'AnoMes': 202108,
#    'Municipio_Ibge': 3123502,
#    'Municipio': 'DOURADOQUARA',
#    'Estado_Ibge': 31,
#    'Estado': 'MINAS GERAIS',
#    'Sigla_Regiao': 'SE',
#    'Regiao': 'SUDESTE',
#    'VL_PagadorPF': 3752504.85,
#    'QT_PagadorPF': 2331,
#    'VL_PagadorPJ': 341025.01,
#    'QT_PagadorPJ': 209,
#    'VL_RecebedorPF': 4026823.33,
#    'QT_RecebedorPF': 2059,
#    'VL_RecebedorPJ': 310415.48,
#    'QT_RecebedorPJ': 236,
#    'QT_PES_PagadorPF': 360,
#    'QT_PES_PagadorPJ': 26,
#    'QT_PES_RecebedorPF': 351,
#    'QT_PES_RecebedorPJ': 25},
#   {'AnoMes': 202303,
#    'Municipio_Ibge': 4312179,
#    'Municipio': 'MATO QUEIMADO',
#    'Estado_Ibge': 43,
#    'Estado': 'RIO GRANDE DO SUL',
#    'Sigla_Regiao': 'SU',
#    'Regiao': 'SUL',
#    'VL_PagadorPF': 1924412.92,
#    'QT_PagadorPF': 6509,
#    'VL_PagadorPJ': 492191.27,
#    'QT_PagadorPJ': 433,
#    'VL_RecebedorPF': 1257808.05,
#    'QT_RecebedorPF': 3603,
#    'VL_RecebedorPJ': 988980.13,
#    'QT_RecebedorPJ': 795,
#    'QT_PES_PagadorPF': 556,
#    'QT_PES_PagadorPJ': 44,
#    'QT_PES_RecebedorPF': 478,
#    'QT_PES_RecebedorPJ': 49},
#   {'AnoMes': 202506,
#    'Municipio_Ibge': 2111789,
#    'Municipio': 'SERRANO DO MARANHÃO',
#    'Estado_Ibge': 21,
#    'Estado': 'MARANHÃO',
#    'Sigla_Regiao': 'NE',
#    'Regiao': 'NORDESTE',
#    'VL_PagadorPF': 17679296.74,
#    'QT_PagadorPF': 186302,
#    'VL_PagadorPJ': 1212865.14,
#    'QT_PagadorPJ': 993,
#    'VL_RecebedorPF': 15834232.31,
#    'QT_RecebedorPF': 116406,
#    'VL_RecebedorPJ': 834975.3,
#    'QT_RecebedorPJ': 8937,
#    'QT_PES_PagadorPF': 4447,
#    'QT_PES_PagadorPJ': 28,
#    'QT_PES_RecebedorPF': 4287,
#    'QT_PES_RecebedorPJ': 28},
#   {'AnoMes': 202102,
#    'Municipio_Ibge': 4104402,
#    'Municipio': 'CÂNDIDO DE ABREU',
#    'Estado_Ibge': 41,
#    'Estado': 'PARANÁ',
#    'Sigla_Regiao': 'SU',
#    'Regiao': 'SUL',
#    'VL_PagadorPF': 1420445.35,
#    'QT_PagadorPF': 3226,
#    'VL_PagadorPJ': 571194.86,
#    'QT_PagadorPJ': 378,
#    'VL_RecebedorPF': 1278803.32,
#    'QT_RecebedorPF': 2972,
#    'VL_RecebedorPJ': 561035.01,
#    'QT_RecebedorPJ': 366,
#    'QT_PES_PagadorPF': 903,
#    'QT_PES_PagadorPJ': 74,
#    'QT_PES_RecebedorPF': 943,
#    'QT_PES_RecebedorPJ': 88},
#   {'AnoMes': 202602,
#    'Municipio_Ibge': 2610103,
#    'Municipio': 'PALMEIRINA',
#    'Estado_Ibge': 26,
#    'Estado': 'PERNAMBUCO',
#    'Sigla_Regiao': 'NE',
#    'Regiao': 'NORDESTE',
#    'VL_PagadorPF': 15827976.23,
#    'QT_PagadorPF': 103229,
#    'VL_PagadorPJ': 1137407.99,
#    'QT_PagadorPJ': 3708,
#    'VL_RecebedorPF': 14422140.69,
#    'QT_RecebedorPF': 59744,
#    'VL_RecebedorPJ': 1286242.42,
#    'QT_RecebedorPJ': 10915,
#    'QT_PES_PagadorPF': 3882,
#    'QT_PES_PagadorPJ': 65,
#    'QT_PES_RecebedorPF': 3706,
#    'QT_PES_RecebedorPJ': 61},
#   {'AnoMes': 202202,
#    'Municipio_Ibge': 3556909,
#    'Municipio': 'VISTA ALEGRE DO ALTO',
#    'Estado_Ibge': 35,
#    'Estado': 'SÃO PAULO',
#    'Sigla_Regiao': 'SE',
#    'Regiao': 'SUDESTE',
#    'VL_PagadorPF': 7371395.03,
#    'QT_PagadorPF': 22393,
#    'VL_PagadorPJ': 18831005.0,
#    'QT_PagadorPJ': 2235,
#    'VL_RecebedorPF': 8444544.77,
#    'QT_RecebedorPF': 17241,
#    'VL_RecebedorPJ': 22218263.73,
#    'QT_RecebedorPJ': 3404,
#    'QT_PES_PagadorPF': 2384,
#    'QT_PES_PagadorPJ': 178,
#    'QT_PES_RecebedorPF': 2212,
#    'QT_PES_RecebedorPJ': 161},
#   {'AnoMes': 202405,
#    'Municipio_Ibge': 4118808,
#    'Municipio': 'PEABIRU',
#    'Estado_Ibge': 41,
#    'Estado': 'PARANÁ',
#    'Sigla_Regiao': 'SU',
#    'Regiao': 'SUL',
#    'VL_PagadorPF': 40208247.69,
#    'QT_PagadorPF': 213301,
#    'VL_PagadorPJ': 30336469.19,
#    'QT_PagadorPJ': 16359,
#    'VL_RecebedorPF': 43176926.31,
#    'QT_RecebedorPF': 113623,
#    'VL_RecebedorPJ': 19071245.32,
#    'QT_RecebedorPJ': 41051,
#    'QT_PES_PagadorPF': 7382,
#    'QT_PES_PagadorPJ': 635,
#    'QT_PES_RecebedorPF': 7244,
#    'QT_PES_RecebedorPJ': 608},
#   {'AnoMes': 202502,
#    'Municipio_Ibge': 2703759,
#    'Municipio': 'JEQUIÁ DA PRAIA',
#    'Estado_Ibge': 27,
#    'Estado': 'ALAGOAS',
#    'Sigla_Regiao': 'NE',
#    'Regiao': 'NORDESTE',
#    'VL_PagadorPF': 21785743.91,
#    'QT_PagadorPF': 175736,
#    'VL_PagadorPJ': 2916857.62,
#    'QT_PagadorPJ': 2961,
#    'VL_RecebedorPF': 20796584.67,
#    'QT_RecebedorPF': 116979,
#    'VL_RecebedorPJ': 3760381.99,
#    'QT_RecebedorPJ': 10166,
#    'QT_PES_PagadorPF': 5283,
#    'QT_PES_PagadorPJ': 121,
#    'QT_PES_RecebedorPF': 5221,
#    'QT_PES_RecebedorPJ': 111},
#   {'AnoMes': 202504,
#    'Municipio_Ibge': 4113502,
#    'Municipio': 'LOANDA',
#    'Estado_Ibge': 41,
#    'Estado': 'PARANÁ',
#    'Sigla_Regiao': 'SU',
#    'Regiao': 'SUL',
#    'VL_PagadorPF': 110243457.6,
#    'QT_PagadorPF': 415635,
#    'VL_PagadorPJ': 172124414.86,
#    'QT_PagadorPJ': 61653,
#    'VL_RecebedorPF': 115578635.73,
#    'QT_RecebedorPF': 233517,
#    'VL_RecebedorPJ': 152004168.76,
#    'QT_RecebedorPJ': 129696,
#    'QT_PES_PagadorPF': 13574,
#    'QT_PES_PagadorPJ': 1778,
#    'QT_PES_RecebedorPF': 13484,
#    'QT_PES_RecebedorPJ': 1746},
#   {'AnoMes': 202101,
#    'Municipio_Ibge': 3144003,
#    'Municipio': 'MUTUM',
#    'Estado_Ibge': 31,
#    'Estado': 'MINAS GERAIS',
#    'Sigla_Regiao': 'SE',
#    'Regiao': 'SUDESTE',
#    'VL_PagadorPF': 4386383.43,
#    'QT_PagadorPF': 8251,
#    'VL_PagadorPJ': 722692.9,
#    'QT_PagadorPJ': 350,
#    'VL_RecebedorPF': 4099802.48,
#    'QT_RecebedorPF': 7745,
#    'VL_RecebedorPJ': 822587.24,
#    'QT_RecebedorPJ': 433,
#    'QT_PES_PagadorPF': 1932,
#    'QT_PES_PagadorPJ': 94,
#    'QT_PES_RecebedorPF': 1898,
#    'QT_PES_RecebedorPJ': 134},
#   {'AnoMes': 202304,
#    'Municipio_Ibge': 3509908,
#    'Municipio': 'CANANÉIA',
#    'Estado_Ibge': 35,
#    'Estado': 'SÃO PAULO',
#    'Sigla_Regiao': 'SE',
#    'Regiao': 'SUDESTE',
#    'VL_PagadorPF': 21917264.72,
#    'QT_PagadorPF': 115358,
#    'VL_PagadorPJ': 5024206.82,
#    'QT_PagadorPJ': 8541,
#    'VL_RecebedorPF': 23809279.19,
#    'QT_RecebedorPF': 84774,
#    'VL_RecebedorPJ': 5561157.03,
#    'QT_RecebedorPJ': 19255,
#    'QT_PES_PagadorPF': 6735,
#    'QT_PES_PagadorPJ': 408,
#    'QT_PES_RecebedorPF': 6724,
#    'QT_PES_RecebedorPJ': 403},
#   {'AnoMes': 202202,
#    'Municipio_Ibge': 4103370,
#    'Municipio': 'BRASILÂNDIA DO SUL',
#    'Estado_Ibge': 41,
#    'Estado': 'PARANÁ',
#    'Sigla_Regiao': 'SU',
#    'Regiao': 'SUL',
#    'VL_PagadorPF': 2965161.2,
#    'QT_PagadorPF': 8471,
#    'VL_PagadorPJ': 808538.18,
#    'QT_PagadorPJ': 557,
#    'VL_RecebedorPF': 2670519.83,
#    'QT_RecebedorPF': 6524,
#    'VL_RecebedorPJ': 591910.13,
#    'QT_RecebedorPJ': 1405,
#    'QT_PES_PagadorPF': 965,
#    'QT_PES_PagadorPJ': 61,
#    'QT_PES_RecebedorPF': 861,
#    'QT_PES_RecebedorPJ': 61},
#   {'AnoMes': 202302,
#    'Municipio_Ibge': 3544400,
#    'Municipio': 'RUBIÁCEA',
#    'Estado_Ibge': 35,
#    'Estado': 'SÃO PAULO',
#    'Sigla_Regiao': 'SE',
#    'Regiao': 'SUDESTE',
#    'VL_PagadorPF': 2951680.22,
#    'QT_PagadorPF': 14382,
#    'VL_PagadorPJ': 538749.74,
#    'QT_PagadorPJ': 669,
#    'VL_RecebedorPF': 2553580.59,
#    'QT_RecebedorPF': 9370,
#    'VL_RecebedorPJ': 753902.59,
#    'QT_RecebedorPJ': 1326,
#    'QT_PES_PagadorPF': 1139,
#    'QT_PES_PagadorPJ': 51,
#    'QT_PES_RecebedorPF': 1085,
#    'QT_PES_RecebedorPJ': 50},
#   {'AnoMes': 202311,
#    'Municipio_Ibge': 3101300,
#    'Municipio': 'ALAGOA',
#    'Estado_Ibge': 31,
#    'Estado': 'MINAS GERAIS',
#    'Sigla_Regiao': 'SE',
#    'Regiao': 'SUDESTE',
#    'VL_PagadorPF': 4704729.87,
#    'QT_PagadorPF': 16568,
#    'VL_PagadorPJ': 1449079.98,
#    'QT_PagadorPJ': 1229,
#    'VL_RecebedorPF': 5503559.22,
#    'QT_RecebedorPF': 11846,
#    'VL_RecebedorPJ': 1592046.32,
#    'QT_RecebedorPJ': 3782,
#    'QT_PES_PagadorPF': 1094,
#    'QT_PES_PagadorPJ': 94,
#    'QT_PES_RecebedorPF': 1089,
#    'QT_PES_RecebedorPJ': 83},
#   {'AnoMes': 202302,
#    'Municipio_Ibge': 2202729,
#    'Municipio': 'COCAL DOS ALVES',
#    'Estado_Ibge': 22,
#    'Estado': 'PIAUÍ',
#    'Sigla_Regiao': 'NE',
#    'Regiao': 'NORDESTE',
#    'VL_PagadorPF': 4658262.43,
#    'QT_PagadorPF': 28094,
#    'VL_PagadorPJ': 772300.89,
#    'QT_PagadorPJ': 762,
#    'VL_RecebedorPF': 4798513.59,
#    'QT_RecebedorPF': 21136,
#    'VL_RecebedorPJ': 619633.98,
#    'QT_RecebedorPJ': 2178,
#    'QT_PES_PagadorPF': 1753,
#    'QT_PES_PagadorPJ': 49,
#    'QT_PES_RecebedorPF': 1781,
#    'QT_PES_RecebedorPJ': 42},
#   {'AnoMes': 202303,
#    'Municipio_Ibge': 3303955,
#    'Municipio': 'PINHEIRAL',
#    'Estado_Ibge': 33,
#    'Estado': 'RIO DE JANEIRO',
#    'Sigla_Regiao': 'SE',
#    'Regiao': 'SUDESTE',
#    'VL_PagadorPF': 39069958.67,
#    'QT_PagadorPF': 234816,
#    'VL_PagadorPJ': 32782487.68,
#    'QT_PagadorPJ': 17622,
#    'VL_RecebedorPF': 39499971.73,
#    'QT_RecebedorPF': 183192,
#    'VL_RecebedorPJ': 38093769.48,
#    'QT_RecebedorPJ': 37060,
#    'QT_PES_PagadorPF': 12294,
#    'QT_PES_PagadorPJ': 703,
#    'QT_PES_RecebedorPF': 12199,
#    'QT_PES_RecebedorPJ': 691},
#   {'AnoMes': 202604,
#    'Municipio_Ibge': 3551306,
#    'Municipio': 'SEBASTIANÓPOLIS DO SUL',
#    'Estado_Ibge': 35,
#    'Estado': 'SÃO PAULO',
#    'Sigla_Regiao': 'SE',
#    'Regiao': 'SUDESTE',
#    'VL_PagadorPF': 13441174.11,
#    'QT_PagadorPF': 61472,
#    'VL_PagadorPJ': 9878450.2,
#    'QT_PagadorPJ': 5790,
#    'VL_RecebedorPF': 13331103.15,
#    'QT_RecebedorPF': 33041,
#    'VL_RecebedorPJ': 10558996.99,
#    'QT_RecebedorPJ': 15591,
#    'QT_PES_PagadorPF': 2093,
#    'QT_PES_PagadorPJ': 211,
#    'QT_PES_RecebedorPF': 1961,
#    'QT_PES_RecebedorPJ': 193},
#   {'AnoMes': 202312,
#    'Municipio_Ibge': 2511400,
#    'Municipio': 'PICUÍ',
#    'Estado_Ibge': 25,
#    'Estado': 'PARAÍBA',
#    'Sigla_Regiao': 'NE',
#    'Regiao': 'NORDESTE',
#    'VL_PagadorPF': 38762930.28,
#    'QT_PagadorPF': 306173,
#    'VL_PagadorPJ': 7968472.24,
#    'QT_PagadorPJ': 16107,
#    'VL_RecebedorPF': 37216357.4,
#    'QT_RecebedorPF': 205631,
#    'VL_RecebedorPJ': 8152181.15,
#    'QT_RecebedorPJ': 57473,
#    'QT_PES_PagadorPF': 9098,
#    'QT_PES_PagadorPJ': 483,
#    'QT_PES_RecebedorPF': 9073,
#    'QT_PES_RecebedorPJ': 429},
#   {'AnoMes': 202309,
#    'Municipio_Ibge': 4126702,
#    'Municipio': 'TAMBOARA',
#    'Estado_Ibge': 41,
#    'Estado': 'PARANÁ',
#    'Sigla_Regiao': 'SU',
#    'Regiao': 'SUL',
#    'VL_PagadorPF': 10965233.67,
#    'QT_PagadorPF': 44668,
#    'VL_PagadorPJ': 27804856.44,
#    'QT_PagadorPJ': 3668,
#    'VL_RecebedorPF': 11904580.86,
#    'QT_RecebedorPF': 25448,
#    'VL_RecebedorPJ': 21322222.67,
#    'QT_RecebedorPJ': 6853,
#    'QT_PES_PagadorPF': 2280,
#    'QT_PES_PagadorPJ': 149,
#    'QT_PES_RecebedorPF': 2171,
#    'QT_PES_RecebedorPJ': 143},
#   {'AnoMes': 202509,
#    'Municipio_Ibge': 2207900,
#    'Municipio': 'PEDRO II',
#    'Estado_Ibge': 22,
#    'Estado': 'PIAUÍ',
#    'Sigla_Regiao': 'NE',
#    'Regiao': 'NORDESTE',
#    'VL_PagadorPF': 88599517.73,
#    'QT_PagadorPF': 663255,
#    'VL_PagadorPJ': 29443179.67,
#    'QT_PagadorPJ': 30875,
#    'VL_RecebedorPF': 84969869.59,
#    'QT_RecebedorPF': 407746,
#    'VL_RecebedorPJ': 25652183.76,
#    'QT_RecebedorPJ': 105319,
#    'QT_PES_PagadorPF': 19527,
#    'QT_PES_PagadorPJ': 778,
#    'QT_PES_RecebedorPF': 19587,
#    'QT_PES_RecebedorPJ': 741},
#   {'AnoMes': 202505,
#    'Municipio_Ibge': 5200852,
#    'Municipio': 'AMERICANO DO BRASIL',
#    'Estado_Ibge': 52,
#    'Estado': 'GOIÁS',
#    'Sigla_Regiao': 'CO',
#    'Regiao': 'CENTRO-OESTE',
#    'VL_PagadorPF': 27867809.88,
#    'QT_PagadorPF': 94090,
#    'VL_PagadorPJ': 5359134.41,
#    'QT_PagadorPJ': 7689,
#    'VL_RecebedorPF': 29491860.03,
#    'QT_RecebedorPF': 60249,
#    'VL_RecebedorPJ': 8852474.31,
#    'QT_RecebedorPJ': 20002,
#    'QT_PES_PagadorPF': 2991,
#    'QT_PES_PagadorPJ': 206,
#    'QT_PES_RecebedorPF': 3087,
#    'QT_PES_RecebedorPJ': 197},
#   {'AnoMes': 202403,
#    'Municipio_Ibge': 4315909,
#    'Municipio': 'RODEIO BONITO',
#    'Estado_Ibge': 43,
#    'Estado': 'RIO GRANDE DO SUL',
#    'Sigla_Regiao': 'SU',
#    'Regiao': 'SUL',
#    'VL_PagadorPF': 16337706.84,
#    'QT_PagadorPF': 58591,
#    'VL_PagadorPJ': 7616940.6,
#    'QT_PagadorPJ': 4775,
#    'VL_RecebedorPF': 28243627.36,
#    'QT_RecebedorPF': 29406,
#    'VL_RecebedorPJ': 9424856.14,
#    'QT_RecebedorPJ': 20203,
#    'QT_PES_PagadorPF': 3051,
#    'QT_PES_PagadorPJ': 375,
#    'QT_PES_RecebedorPF': 2660,
#    'QT_PES_RecebedorPJ': 378},
#   {'AnoMes': 202602,
#    'Municipio_Ibge': 1702307,
#    'Municipio': 'ARAPOEMA',
#    'Estado_Ibge': 17,
#    'Estado': 'TOCANTINS',
#    'Sigla_Regiao': 'NO',
#    'Regiao': 'NORTE',
#    'VL_PagadorPF': 31621495.07,
#    'QT_PagadorPF': 165752,
#    'VL_PagadorPJ': 7603896.14,
#    'QT_PagadorPJ': 6490,
#    'VL_RecebedorPF': 35572109.09,
#    'QT_RecebedorPF': 83700,
#    'VL_RecebedorPJ': 6739003.76,
#    'QT_RecebedorPJ': 22844,
#    'QT_PES_PagadorPF': 4384,
#    'QT_PES_PagadorPJ': 180,
#    'QT_PES_RecebedorPF': 4218,
#    'QT_PES_RecebedorPJ': 168},
#   {'AnoMes': 202106,
#    'Municipio_Ibge': 2200400,
#    'Municipio': 'ALTOS',
#    'Estado_Ibge': 22,
#    'Estado': 'PIAUÍ',
#    'Sigla_Regiao': 'NE',
#    'Regiao': 'NORDESTE',
#    'VL_PagadorPF': 15701164.03,
#    'QT_PagadorPF': 67110,
#    'VL_PagadorPJ': 7577870.09,
#    'QT_PagadorPJ': 3651,
#    'VL_RecebedorPF': 15755071.01,
#    'QT_RecebedorPF': 73478,
#    'VL_RecebedorPJ': 5914596.73,
#    'QT_RecebedorPJ': 4491,
#    'QT_PES_PagadorPF': 7930,
#    'QT_PES_PagadorPJ': 278,
#    'QT_PES_RecebedorPF': 8806,
#    'QT_PES_RecebedorPJ': 292},
#   {'AnoMes': 202210,
#    'Municipio_Ibge': 4215356,
#    'Municipio': 'SALTINHO',
#    'Estado_Ibge': 42,
#    'Estado': 'SANTA CATARINA',
#    'Sigla_Regiao': 'SU',
#    'Regiao': 'SUL',
#    'VL_PagadorPF': 2865227.99,
#    'QT_PagadorPF': 9152,
#    'VL_PagadorPJ': 710041.85,
#    'QT_PagadorPJ': 893,
#    'VL_RecebedorPF': 2459812.97,
#    'QT_RecebedorPF': 5185,
#    'VL_RecebedorPJ': 749046.9,
#    'QT_RecebedorPJ': 1891,
#    'QT_PES_PagadorPF': 1128,
#    'QT_PES_PagadorPJ': 86,
#    'QT_PES_RecebedorPF': 954,
#    'QT_PES_RecebedorPJ': 90},
#   ...]}

# %%
len(data['value'])
# Out:
# 378731

# %%
# Dataframe para facilitar a analise

# Min AnoMes = 202011 --> quando o Pix foi lançado
# Max AnoMes = 202606 --> mes atual
df = pd.DataFrame(data["value"]).reset_index(drop=True)
df.head()
# Out:
#    AnoMes  Municipio_Ibge         Municipio  Estado_Ibge             Estado  \
# 0  202202       4311759.0      MANOEL VIANA         43.0  RIO GRANDE DO SUL
# 1  202304       2927002.0          RIO REAL         29.0              BAHIA
# 2  202511       3540804.0       POTIRENDABA         35.0          SÃO PAULO
# 3  202401       4302253.0  BOA VISTA DO SUL         43.0  RIO GRANDE DO SUL
# 4  202408       3140506.0   MARTINHO CAMPOS         31.0       MINAS GERAIS
#
#   Sigla_Regiao    Regiao  VL_PagadorPF  QT_PagadorPF  VL_PagadorPJ  \
# 0           SU       SUL    5948465.27         17864    1274988.24
# 1           NE  NORDESTE   60409884.10        278219   25903682.63
# 2           SE   SUDESTE   85492055.59        342121   61190139.79
# 3           SU       SUL    3610350.44         10670   14311310.00
# 4           SE   SUDESTE   44522987.65        200535   32940595.09
#
#    QT_PagadorPJ  VL_RecebedorPF  QT_RecebedorPF  VL_RecebedorPJ  \
# 0          1636      5728446.02           12828      1966939.92
# 1         12349     61247709.25          210020     26085325.94
# 2         32172     88789714.11          192660     55561592.86
# 3          1499      4278357.47            6194     11034876.53
# 4         12797     44434260.10          113044     44171305.79
#
#    QT_RecebedorPJ  QT_PES_PagadorPF  QT_PES_PagadorPJ  QT_PES_RecebedorPF  \
# 0            3744              2054               151                1827
# 1           33238             14291               566               14802
# 2           82573             10779              1012               10456
# 3            1769               851                95                 752
# 4           42227              7575               787                7392
#
#    QT_PES_RecebedorPJ
# 0                 153
# 1                 555
# 2                 925
# 3                  86
# 4                 692

# %%
df["AnoMes"].value_counts().reset_index().sort_values(by='AnoMes')
df.shape
# Out:
# (378731, 19)

# %% [markdown]
# ## Perguntas de exploração — Feature 3

# %%
# 1. Paginação — a API retorna tudo em uma chamada ou há @odata.nextLink?
print("@odata.nextLink presente:", "@odata.nextLink" in data)
print("@odata.count presente:", "@odata.count" in data)
print("Total registros retornados:", len(data["value"]))
# Out:
# @odata.nextLink presente: False
# @odata.count presente: False
# Total registros retornados: 378731

# %%
# 2. Cobertura municipal — quantos municípios distintos? Todos os 5.571?
print("Municípios distintos na base:", df["Municipio_Ibge"].nunique())
print("Municípios esperados (IBGE):", 5571)
print("Diferença:", 5571 - df["Municipio_Ibge"].nunique())
# Out:
# Municípios distintos na base: 5571
# Municípios esperados (IBGE): 5571
# Diferença: 0

# %%
# 3. Lag de publicação — qual o AnoMes mais recente disponível?
print("AnoMes mais recente:", df["AnoMes"].max())
print("AnoMes mais antigo:", df["AnoMes"].min())
print("Meses distintos:", df["AnoMes"].nunique())

# Quantos municípios têm dado no mês mais recente?
mes_recente = df["AnoMes"].max()
cobertura_recente = df[df["AnoMes"] == mes_recente]["Municipio_Ibge"].nunique()
print(f"Municípios com dado em {mes_recente}:", cobertura_recente)
# Out:
# AnoMes mais recente: 202606
# AnoMes mais antigo: 202011
# Meses distintos: 68
# Municípios com dado em 202606: 5571

# %%
# 4. Nulos — quais colunas têm valores nulos?
nulos = df.isnull().sum()
print("Nulos por coluna:")
print(nulos[nulos > 0] if nulos.sum() > 0 else "Nenhum nulo encontrado")
# Out:
# Nulos por coluna:
# Municipio_Ibge    68
# Estado_Ibge       68
# Sigla_Regiao      68
# dtype: int64

# %% [markdown]
# apesar do numero estar abaixo do esperado pode ter sido criado novos municipios

# %%
# 5. Municípios sem cobertura em algum mês — há gaps?
# Esperado: 5571 municípios × n meses
total_meses = df["AnoMes"].nunique()
total_municipios = df["Municipio_Ibge"].nunique()
combinacoes_esperadas = total_meses * total_municipios
combinacoes_reais = len(df)
print(f"Meses: {total_meses}, Municípios: {total_municipios}")
print(f"Combinações esperadas (sem gaps): {combinacoes_esperadas}")
print(f"Combinações reais: {combinacoes_reais}")
print(f"Registros faltando: {combinacoes_esperadas - combinacoes_reais}")
# Out:
# Meses: 68, Municípios: 5571
# Combinações esperadas (sem gaps): 378828
# Combinações reais: 378731
# Registros faltando: 97

# %%
# 6. Schema completo — tipos reais de cada coluna
print(df.dtypes)
print("\nAmostra de um registro:")
print(df.iloc[0].to_dict())
# Out:
# AnoMes                  int64
# Municipio_Ibge        float64
# Municipio                 str
# Estado_Ibge           float64
# Estado                    str
# Sigla_Regiao              str
# Regiao                    str
# VL_PagadorPF          float64
# QT_PagadorPF            int64
# VL_PagadorPJ          float64
# QT_PagadorPJ            int64
# VL_RecebedorPF        float64
# QT_RecebedorPF          int64
# VL_RecebedorPJ        float64
# QT_RecebedorPJ          int64
# QT_PES_PagadorPF        int64
# QT_PES_PagadorPJ        int64
# QT_PES_RecebedorPF      int64
# QT_PES_RecebedorPJ      int64
# dtype: object
#
# Amostra de um registro:
# {'AnoMes': 202202, 'Municipio_Ibge': 4311759.0, 'Municipio': 'MANOEL VIANA', 'Estado_Ibge': 43.0, 'Estado': 'RIO GRANDE DO SUL', 'Sigla_Regiao': 'SU', 'Regiao': 'SUL', 'VL_PagadorPF': 5948465.27, 'QT_PagadorPF': 17864, 'VL_PagadorPJ': 1274988.24, 'QT_PagadorPJ': 1636, 'VL_RecebedorPF': 5728446.02, 'QT_RecebedorPF': 12828, 'VL_RecebedorPJ': 1966939.92, 'QT_RecebedorPJ': 3744, 'QT_PES_PagadorPF': 2054, 'QT_PES_PagadorPJ': 151, 'QT_PES_RecebedorPF': 1827, 'QT_PES_RecebedorPJ': 153}
